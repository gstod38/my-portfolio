# %% [markdown]
# # Beta Bank Churn Project:
#
# - Customers are leaving the bank slowly, financially it makes most since to retain customers rather than attract new ones.
# - The goal is to create a model to predict whether customers will leave the bank.
# - Our target for model testing will be a minimum F1 score of 0.59.
# - Models tested will include: Logistic Regression, Decision Tree Classifier, Random Forest Classifier.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %% [markdown]
# ## Data Preperation:

# %%
data = pd.read_csv('Churn.csv')
display(data.head())
data.info()
#display(data['Tenure'].value_counts())
#display(data['Geography'].value_counts())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
print(data.isnull().sum())
print(data.describe())
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data['Tenure'] = data['Tenure'].fillna(data['Tenure'].median())
print(data.isnull().sum())
display(data.describe())
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.00000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      4.99790
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.76001
# min        1.00000  1.556570e+07    350.000000     18.000000      0.00000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.00000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.00000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.00000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.00000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
data = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
display(data.head())
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42     2.0       0.00              1
# 1          608     Spain  Female   41     1.0   83807.86              1
# 2          502    France  Female   42     8.0  159660.80              3
# 3          699    France  Female   39     1.0       0.00              2
# 4          850     Spain  Female   43     2.0  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data['Tenure'] = data['Tenure'].astype('int64')
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB
# None

# %% [markdown]
# - Our data was fairly intact with only the Tenure column reflecting missing values. To handle this we filled the missing values with the median in an effort to not distort the data.
#     - Before/After statistical analysis of the Tenure column reflects that our filling of missing values with the 'median' had negligable effect on its overall stats.
#         - The mean changed from 4.99769 to 4.9979. This makes sense, our mean and median values are very close.
#         - Std Dev also slightly changed from 2.894723 to 2.76001. This slight change is to be expected after filling 809 missing values. Because our mean and median are similar in value, a significant change in the std dev wasn't expected during our fill process.
# - RowNumber, CustomerID and Surname have been removed from the data since that information will not be relevant to our models success.
# - Data Types adjusted to accurately reflect the data.

# %% [markdown]
# ## Imbalance of Classes:

# %%
data['Exited'].value_counts().plot(kind='bar', rot=1)
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# - Clearly our data reflects a large imbalance showing a roughly 4:1 ratio of customers that stay vs customers that leave.
# - This imbalance will need to be accounted for in the model training in order to accurately create a model that can predict customer churn.

# %% [markdown]
# ## Initial Model Training:

# %%
data_ohe = pd.get_dummies(data, drop_first=True)
display(data_ohe.head(10))
target = data_ohe['Exited']
features = data_ohe.drop('Exited', axis=1)
features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.5, random_state=12345)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, target_valid, test_size=0.5, random_state=12345)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
# 5          645   44       8  113755.78              2          1
# 6          822   50       7       0.00              2          1
# 7          376   29       4  115046.74              4          1
# 8          501   44       4  142051.07              2          0
# 9          684   27       2  134603.88              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
# 5               0        149756.71       1              False
# 6               1         10062.80       0              False
# 7               0        119346.88       1               True
# 8               1         74940.50       0              False
# 9               1         71725.73       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False
# 5             True         True
# 6            False         True
# 7            False        False
# 8            False         True
# 9            False         True

# %%
# Logistic Regression with hyperparameter tuning for unbalanced data
best_c = 0
best_f1 = 0
for c in [0.01, 0.1, 1, 10]:
    model = LogisticRegression(solver='liblinear', C=c, random_state=12345)
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'C={c}, f1 score={current_f1}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_c = c
print(f'Best C: {best_c}, Best f1 score: {best_f1}')
# Out:
# C=0.01, f1 score=0.11352253756260434
# C=0.1, f1 score=0.11352253756260434
# C=1, f1 score=0.11352253756260434
# C=10, f1 score=0.11352253756260434
# Best C: 0.01, Best f1 score: 0.11352253756260434
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
# Decision Tree Classifier with hyperparameter tuning for unbalanced data
best_depth = 0
best_f1 = 0
for depth in range(1, 11):
    model = DecisionTreeClassifier(max_depth=depth, random_state=12345)
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'Depth={depth}, f1 score={current_f1}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_depth = depth
print(f'Best Depth: {best_depth}, Best f1 score: {best_f1}')
# Out:
# Depth=1, f1 score=0.0
# Depth=2, f1 score=0.49158249158249157
# Depth=3, f1 score=0.44660194174757284
# Depth=4, f1 score=0.4707482993197279
# Depth=5, f1 score=0.5246305418719212
# Depth=6, f1 score=0.4826629680998613
# Depth=7, f1 score=0.5303210463733651
# Depth=8, f1 score=0.5182567726737338
# Depth=9, f1 score=0.4988399071925754
# Depth=10, f1 score=0.49002217294900224
# Best Depth: 7, Best f1 score: 0.5303210463733651

# %%
# Random Forest Classifier with hyperparameter tuning for unbalanced data
best_depth = 0
best_f1 = 0
best_est = 0
for depth in range(1, 26):
    for est in range(1,51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345)
        model.fit(features_train, target_train)
        predictions = model.predict(features_valid)
        current_f1 = f1_score(target_valid, predictions)
        #print(f'Depth={depth}, Estimators={est}, f1 score={current_f1}')
        if current_f1 > best_f1:
            best_f1 = current_f1
            best_depth = depth
            best_est = est
print(f'Best Depth: {best_depth}, Best Estimators: {best_est}, Best f1 score: {best_f1}')
# Out:
# Depth=1, Estimators=1, f1 score=0.2222222222222222
# Depth=1, Estimators=2, f1 score=0.21649484536082475
# Depth=1, Estimators=3, f1 score=0.0
# Depth=1, Estimators=4, f1 score=0.0
# Depth=1, Estimators=5, f1 score=0.1042830540037244
# Depth=1, Estimators=6, f1 score=0.0
# Depth=1, Estimators=7, f1 score=0.0
# Depth=1, Estimators=8, f1 score=0.0
# Depth=1, Estimators=9, f1 score=0.0
# Depth=1, Estimators=10, f1 score=0.0
# Depth=1, Estimators=11, f1 score=0.0
# Depth=1, Estimators=12, f1 score=0.0
# Depth=1, Estimators=13, f1 score=0.0
# Depth=1, Estimators=14, f1 score=0.0
# Depth=1, Estimators=15, f1 score=0.0
# Depth=1, Estimators=16, f1 score=0.0
# Depth=1, Estimators=17, f1 score=0.0
# Depth=1, Estimators=18, f1 score=0.0
# Depth=1, Estimators=19, f1 score=0.0
# Depth=1, Estimators=20, f1 score=0.0
# Depth=1, Estimators=21, f1 score=0.0
# Depth=1, Estimators=22, f1 score=0.0
# Depth=1, Estimators=23, f1 score=0.0
# Depth=1, Estimators=24, f1 score=0.0
# Depth=1, Estimators=25, f1 score=0.0
# Depth=1, Estimators=26, f1 score=0.0
# Depth=1, Estimators=27, f1 score=0.0
# Depth=1, Estimators=28, f1 score=0.0
# Depth=1, Estimators=29, f1 score=0.0
# Depth=1, Estimators=30, f1 score=0.0
# Depth=1, Estimators=31, f1 score=0.0
# Depth=1, Estimators=32, f1 score=0.0
# Depth=1, Estimators=33, f1 score=0.0
# Depth=1, Estimators=34, f1 score=0.0
# Depth=1, Estimators=35, f1 score=0.0
# Depth=1, Estimators=36, f1 score=0.0
# Depth=1, Estimators=37, f1 score=0.0
# Depth=1, Estimators=38, f1 score=0.0
# Depth=1, Estimators=39, f1 score=0.0
# Depth=1, Estimators=40, f1 score=0.0
# Depth=1, Estimators=41, f1 score=0.0
# Depth=1, Estimators=42, f1 score=0.0
# Depth=1, Estimators=43, f1 score=0.0
# Depth=1, Estimators=44, f1 score=0.0
# Depth=1, Estimators=45, f1 score=0.0
# Depth=1, Estimators=46, f1 score=0.0
# Depth=1, Estimators=47, f1 score=0.0
# Depth=1, Estimators=48, f1 score=0.0
# Depth=1, Estimators=49, f1 score=0.0
# Depth=1, Estimators=50, f1 score=0.0
# Depth=2, Estimators=1, f1 score=0.2222222222222222
# Depth=2, Estimators=2, f1 score=0.13186813186813187
# Depth=2, Estimators=3, f1 score=0.10780669144981413
# Depth=2, Estimators=4, f1 score=0.10780669144981413
# Depth=2, Estimators=5, f1 score=0.10780669144981413
# Depth=2, Estimators=6, f1 score=0.13503649635036497
# Depth=2, Estimators=7, f1 score=0.17761989342806395
# Depth=2, Estimators=8, f1 score=0.17761989342806395
# Depth=2, Estimators=9, f1 score=0.1773049645390071
# Depth=2, Estimators=10, f1 score=0.17761989342806395
# Depth=2, Estimators=11, f1 score=0.17761989342806395
# Depth=2, Estimators=12, f1 score=0.17761989342806395
# Depth=2, Estimators=13, f1 score=0.17761989342806395
# Depth=2, Estimators=14, f1 score=0.17761989342806395
# Depth=2, Estimators=15, f1 score=0.17761989342806395
# Depth=2, Estimators=16, f1 score=0.14207650273224043
# Depth=2, Estimators=17, f1 score=0.12867647058823528
# Depth=2, Estimators=18, f1 score=0.11829944547134935
# Depth=2, Estimators=19, f1 score=0.11829944547134935
# Depth=2, Estimators=20, f1 score=0.10800744878957169
# Depth=2, Estimators=21, f1 score=0.10780669144981413
# Depth=2, Estimators=22, f1 score=0.10780669144981413
# Depth=2, Estimators=23, f1 score=0.10780669144981413
# Depth=2, Estimators=24, f1 score=0.11481481481481481
# Depth=2, Estimators=25, f1 score=0.10093457943925234
# Depth=2, Estimators=26, f1 score=0.09380863039399624
# Depth=2, Estimators=27, f1 score=0.10093457943925234
# Depth=2, Estimators=28, f1 score=0.09380863039399624
# Depth=2, Estimators=29, f1 score=0.09380863039399624
# Depth=2, Estimators=30, f1 score=0.09022556390977443
# Depth=2, Estimators=31, f1 score=0.09022556390977443
# Depth=2, Estimators=32, f1 score=0.09380863039399624
# Depth=2, Estimators=33, f1 score=0.09022556390977443
# Depth=2, Estimators=34, f1 score=0.1044776119402985
# Depth=2, Estimators=35, f1 score=0.11152416356877323
# Depth=2, Estimators=36, f1 score=0.12177121771217712
# Depth=2, Estimators=37, f1 score=0.14181818181818182
# Depth=2, Estimators=38, f1 score=0.12867647058823528
# Depth=2, Estimators=39, f1 score=0.11131725417439703
# Depth=2, Estimators=40, f1 score=0.11152416356877323
# Depth=2, Estimators=41, f1 score=0.11152416356877323
# Depth=2, Estimators=42, f1 score=0.12546125461254612
# Depth=2, Estimators=43, f1 score=0.1150278293135436
# Depth=2, Estimators=44, f1 score=0.11851851851851852
# Depth=2, Estimators=45, f1 score=0.12867647058823528
# Depth=2, Estimators=46, f1 score=0.14571948998178508
# Depth=2, Estimators=47, f1 score=0.12867647058823528
# Depth=2, Estimators=48, f1 score=0.12546125461254612
# Depth=2, Estimators=49, f1 score=0.12867647058823528
# Depth=2, Estimators=50, f1 score=0.14233576642335766
# Depth=3, Estimators=1, f1 score=0.1875
# Depth=3, Estimators=2, f1 score=0.1552346570397112
# Depth=3, Estimators=3, f1 score=0.36289222373806274
# Depth=3, Estimators=4, f1 score=0.28526148969889065
# Depth=3, Estimators=5, f1 score=0.3266563944530046
# Depth=3, Estimators=6, f1 score=0.33746130030959753
# Depth=3, Estimators=7, f1 score=0.3516819571865443
# Depth=3, Estimators=8, f1 score=0.281505728314239
# Depth=3, Estimators=9, f1 score=0.281505728314239
# Depth=3, Estimators=10, f1 score=0.24149659863945577
# Depth=3, Estimators=11, f1 score=0.27
# Depth=3, Estimators=12, f1 score=0.24190800681431004
# Depth=3, Estimators=13, f1 score=0.23208191126279865
# Depth=3, Estimators=14, f1 score=0.22758620689655173
# Depth=3, Estimators=15, f1 score=0.22298456260720412
# Depth=3, Estimators=16, f1 score=0.2179930795847751
# Depth=3, Estimators=17, f1 score=0.2206896551724138
# Depth=3, Estimators=18, f1 score=0.21180555555555555
# Depth=3, Estimators=19, f1 score=0.22375215146299485
# Depth=3, Estimators=20, f1 score=0.21490467937608318
# Depth=3, Estimators=21, f1 score=0.22107081174438686
# Depth=3, Estimators=22, f1 score=0.21490467937608318
# Depth=3, Estimators=23, f1 score=0.20869565217391303
# Depth=3, Estimators=24, f1 score=0.21180555555555555
# Depth=3, Estimators=25, f1 score=0.20593368237347295
# Depth=3, Estimators=26, f1 score=0.20593368237347295
# Depth=3, Estimators=27, f1 score=0.2152777777777778
# Depth=3, Estimators=28, f1 score=0.23024054982817868
# Depth=3, Estimators=29, f1 score=0.2332761578044597
# Depth=3, Estimators=30, f1 score=0.23024054982817868
# Depth=3, Estimators=31, f1 score=0.2453151618398637
# Depth=3, Estimators=32, f1 score=0.23890784982935154
# Depth=3, Estimators=33, f1 score=0.2332761578044597
# Depth=3, Estimators=34, f1 score=0.2332761578044597
# Depth=3, Estimators=35, f1 score=0.24448217317487267
# Depth=3, Estimators=36, f1 score=0.24489795918367346
# Depth=3, Estimators=37, f1 score=0.23024054982817868
# Depth=3, Estimators=38, f1 score=0.2533783783783784
# Depth=3, Estimators=39, f1 score=0.25546218487394956
# Depth=3, Estimators=40, f1 score=0.26421404682274247
# Depth=3, Estimators=41, f1 score=0.27107438016528923
# Depth=3, Estimators=42, f1 score=0.2706270627062706
# Depth=3, Estimators=43, f1 score=0.2682119205298013
# Depth=3, Estimators=44, f1 score=0.26666666666666666
# Depth=3, Estimators=45, f1 score=0.27483443708609273
# Depth=3, Estimators=46, f1 score=0.27483443708609273
# Depth=3, Estimators=47, f1 score=0.27483443708609273
# Depth=3, Estimators=48, f1 score=0.27768595041322314
# Depth=3, Estimators=49, f1 score=0.28618421052631576
# Depth=3, Estimators=50, f1 score=0.2724252491694352
# Depth=4, Estimators=1, f1 score=0.5006257822277848
# Depth=4, Estimators=2, f1 score=0.43175487465181056
# Depth=4, Estimators=3, f1 score=0.35
# Depth=4, Estimators=4, f1 score=0.40285714285714286
# Depth=4, Estimators=5, f1 score=0.3536404160475483
# Depth=4, Estimators=6, f1 score=0.3359253499222395
# Depth=4, Estimators=7, f1 score=0.3248407643312102
# Depth=4, Estimators=8, f1 score=0.3343949044585987
# Depth=4, Estimators=9, f1 score=0.3755725190839695
# Depth=4, Estimators=10, f1 score=0.3375
# Depth=4, Estimators=11, f1 score=0.33385826771653543
# Depth=4, Estimators=12, f1 score=0.3385579937304075
# Depth=4, Estimators=13, f1 score=0.33068362480127184
# Depth=4, Estimators=14, f1 score=0.3328050713153724
# Depth=4, Estimators=15, f1 score=0.32
# Depth=4, Estimators=16, f1 score=0.31781701444622795
# Depth=4, Estimators=17, f1 score=0.3328050713153724
# Depth=4, Estimators=18, f1 score=0.37116564417177916
# Depth=4, Estimators=19, f1 score=0.39097744360902253
# Depth=4, Estimators=20, f1 score=0.37116564417177916
# Depth=4, Estimators=21, f1 score=0.38239757207890746
# Depth=4, Estimators=22, f1 score=0.3730886850152905
# Depth=4, Estimators=23, f1 score=0.3728813559322034
# Depth=4, Estimators=24, f1 score=0.35968992248062015
# Depth=4, Estimators=25, f1 score=0.3514774494556765
# Depth=4, Estimators=26, f1 score=0.3390894819466248
# Depth=4, Estimators=27, f1 score=0.335423197492163
# Depth=4, Estimators=28, f1 score=0.3312302839116719
# Depth=4, Estimators=29, f1 score=0.3328050713153724
# Depth=4, Estimators=30, f1 score=0.334384858044164
# Depth=4, Estimators=31, f1 score=0.33385826771653543
# Depth=4, Estimators=32, f1 score=0.33860759493670883
# Depth=4, Estimators=33, f1 score=0.32802547770700635
# Depth=4, Estimators=34, f1 score=0.3401574803149606
# Depth=4, Estimators=35, f1 score=0.33700787401574805
# Depth=4, Estimators=36, f1 score=0.3380726698262243
# Depth=4, Estimators=37, f1 score=0.33650793650793653
# Depth=4, Estimators=38, f1 score=0.3359746434231379
# Depth=4, Estimators=39, f1 score=0.34330708661417325
# Depth=4, Estimators=40, f1 score=0.3401574803149606
# Depth=4, Estimators=41, f1 score=0.3453689167974882
# Depth=4, Estimators=42, f1 score=0.3448275862068966
# Depth=4, Estimators=43, f1 score=0.3448275862068966
# Depth=4, Estimators=44, f1 score=0.3448275862068966
# Depth=4, Estimators=45, f1 score=0.3453689167974882
# Depth=4, Estimators=46, f1 score=0.35
# Depth=4, Estimators=47, f1 score=0.36728395061728397
# Depth=4, Estimators=48, f1 score=0.37366003062787134
# Depth=4, Estimators=49, f1 score=0.3774733637747336
# Depth=4, Estimators=50, f1 score=0.37366003062787134
# Depth=5, Estimators=1, f1 score=0.5006257822277848
# Depth=5, Estimators=2, f1 score=0.49056603773584906
# Depth=5, Estimators=3, f1 score=0.5061425061425061
# Depth=5, Estimators=4, f1 score=0.48711340206185566
# Depth=5, Estimators=5, f1 score=0.49282920469361147
# Depth=5, Estimators=6, f1 score=0.49595687331536387
# Depth=5, Estimators=7, f1 score=0.4979811574697174
# Depth=5, Estimators=8, f1 score=0.5134408602150538
# Depth=5, Estimators=9, f1 score=0.514745308310992
# Depth=5, Estimators=10, f1 score=0.5201072386058981
# Depth=5, Estimators=11, f1 score=0.5141318977119784
# Depth=5, Estimators=12, f1 score=0.5067385444743935
# Depth=5, Estimators=13, f1 score=0.514745308310992
# Depth=5, Estimators=14, f1 score=0.5093333333333333
# Depth=5, Estimators=15, f1 score=0.5100671140939598
# Depth=5, Estimators=16, f1 score=0.4993252361673414
# Depth=5, Estimators=17, f1 score=0.5154362416107383
# Depth=5, Estimators=18, f1 score=0.5034013605442177
# Depth=5, Estimators=19, f1 score=0.5006802721088436
# Depth=5, Estimators=20, f1 score=0.5
# Depth=5, Estimators=21, f1 score=0.5054347826086957
# Depth=5, Estimators=22, f1 score=0.4986376021798365
# Depth=5, Estimators=23, f1 score=0.4986301369863014
# Depth=5, Estimators=24, f1 score=0.49108367626886146
# Depth=5, Estimators=25, f1 score=0.5034013605442177
# Depth=5, Estimators=26, f1 score=0.49591280653950953
# Depth=5, Estimators=27, f1 score=0.49108367626886146
# Depth=5, Estimators=28, f1 score=0.4904109589041096
# Depth=5, Estimators=29, f1 score=0.48551724137931035
# Depth=5, Estimators=30, f1 score=0.4792243767313019
# Depth=5, Estimators=31, f1 score=0.4814305364511692
# Depth=5, Estimators=32, f1 score=0.48551724137931035
# Depth=5, Estimators=33, f1 score=0.4727272727272727
# Depth=5, Estimators=34, f1 score=0.4591549295774648
# Depth=5, Estimators=35, f1 score=0.4699300699300699
# Depth=5, Estimators=36, f1 score=0.46629213483146065
# Depth=5, Estimators=37, f1 score=0.4604519774011299
# Depth=5, Estimators=38, f1 score=0.4727272727272727
# Depth=5, Estimators=39, f1 score=0.4619718309859155
# Depth=5, Estimators=40, f1 score=0.4684431977559607
# Depth=5, Estimators=41, f1 score=0.44950213371266
# Depth=5, Estimators=42, f1 score=0.4677871148459384
# Depth=5, Estimators=43, f1 score=0.45544554455445546
# Depth=5, Estimators=44, f1 score=0.4523470839260313
# Depth=5, Estimators=45, f1 score=0.4523470839260313
# Depth=5, Estimators=46, f1 score=0.45519203413940257
# Depth=5, Estimators=47, f1 score=0.46544428772919605
# Depth=5, Estimators=48, f1 score=0.47058823529411764
# Depth=5, Estimators=49, f1 score=0.4735376044568245
# Depth=5, Estimators=50, f1 score=0.46629213483146065
# Depth=6, Estimators=1, f1 score=0.3582089552238806
# Depth=6, Estimators=2, f1 score=0.33933933933933935
# Depth=6, Estimators=3, f1 score=0.4472573839662447
# Depth=6, Estimators=4, f1 score=0.4797843665768194
# Depth=6, Estimators=5, f1 score=0.5046728971962616
# Depth=6, Estimators=6, f1 score=0.49386084583901774
# Depth=6, Estimators=7, f1 score=0.5134408602150538
# Depth=6, Estimators=8, f1 score=0.4986376021798365
# Depth=6, Estimators=9, f1 score=0.5135135135135135
# Depth=6, Estimators=10, f1 score=0.5060893098782138
# Depth=6, Estimators=11, f1 score=0.5013623978201635
# Depth=6, Estimators=12, f1 score=0.4889502762430939
# Depth=6, Estimators=13, f1 score=0.4986376021798365
# Depth=6, Estimators=14, f1 score=0.5040650406504065
# Depth=6, Estimators=15, f1 score=0.5034013605442177
# Depth=6, Estimators=16, f1 score=0.5128205128205128
# Depth=6, Estimators=17, f1 score=0.5142857142857142
# Depth=6, Estimators=18, f1 score=0.508843537414966
# Depth=6, Estimators=19, f1 score=0.5094850948509485
# Depth=6, Estimators=20, f1 score=0.5101763907734057
# Depth=6, Estimators=21, f1 score=0.5101763907734057
# Depth=6, Estimators=22, f1 score=0.5182186234817814
# Depth=6, Estimators=23, f1 score=0.516914749661705
# Depth=6, Estimators=24, f1 score=0.5162162162162162
# Depth=6, Estimators=25, f1 score=0.5175202156334232
# Depth=6, Estimators=26, f1 score=0.5175202156334232
# Depth=6, Estimators=27, f1 score=0.5202156334231806
# Depth=6, Estimators=28, f1 score=0.5209176788124157
# Depth=6, Estimators=29, f1 score=0.5182186234817814
# Depth=6, Estimators=30, f1 score=0.5142083897158322
# Depth=6, Estimators=31, f1 score=0.5149051490514905
# Depth=6, Estimators=32, f1 score=0.5128900949796472
# Depth=6, Estimators=33, f1 score=0.5109289617486339
# Depth=6, Estimators=34, f1 score=0.5102319236016372
# Depth=6, Estimators=35, f1 score=0.5081967213114754
# Depth=6, Estimators=36, f1 score=0.505464480874317
# Depth=6, Estimators=37, f1 score=0.5068493150684932
# Depth=6, Estimators=38, f1 score=0.5102319236016372
# Depth=6, Estimators=39, f1 score=0.5136612021857924
# Depth=6, Estimators=40, f1 score=0.5109289617486339
# Depth=6, Estimators=41, f1 score=0.5116279069767442
# Depth=6, Estimators=42, f1 score=0.5142857142857142
# Depth=6, Estimators=43, f1 score=0.5109289617486339
# Depth=6, Estimators=44, f1 score=0.5068493150684932
# Depth=6, Estimators=45, f1 score=0.5081967213114754
# Depth=6, Estimators=46, f1 score=0.5068493150684932
# Depth=6, Estimators=47, f1 score=0.5122615803814714
# Depth=6, Estimators=48, f1 score=0.5068119891008175
# Depth=6, Estimators=49, f1 score=0.5115646258503401
# Depth=6, Estimators=50, f1 score=0.5041095890410959
# Depth=7, Estimators=1, f1 score=0.42118537200504413
# Depth=7, Estimators=2, f1 score=0.5157384987893463
# Depth=7, Estimators=3, f1 score=0.49222797927461137
# Depth=7, Estimators=4, f1 score=0.5216284987277354
# Depth=7, Estimators=5, f1 score=0.5118110236220472
# Depth=7, Estimators=6, f1 score=0.4939919893190921
# Depth=7, Estimators=7, f1 score=0.5006587615283268
# Depth=7, Estimators=8, f1 score=0.5214007782101168
# Depth=7, Estimators=9, f1 score=0.5233160621761658
# Depth=7, Estimators=10, f1 score=0.5182291666666666
# Depth=7, Estimators=11, f1 score=0.5233160621761658
# Depth=7, Estimators=12, f1 score=0.522077922077922
# Depth=7, Estimators=13, f1 score=0.5177398160315374
# Depth=7, Estimators=14, f1 score=0.5210526315789473
# Depth=7, Estimators=15, f1 score=0.5151915455746368
# Depth=7, Estimators=16, f1 score=0.5177398160315374
# Depth=7, Estimators=17, f1 score=0.5238095238095238
# Depth=7, Estimators=18, f1 score=0.5211640211640212
# Depth=7, Estimators=19, f1 score=0.5285524568393094
# Depth=7, Estimators=20, f1 score=0.5233644859813084
# Depth=7, Estimators=21, f1 score=0.5173333333333333
# Depth=7, Estimators=22, f1 score=0.5226666666666666
# Depth=7, Estimators=23, f1 score=0.53315649867374
# Depth=7, Estimators=24, f1 score=0.5299600532623169
# Depth=7, Estimators=25, f1 score=0.5292553191489362
# Depth=7, Estimators=26, f1 score=0.528
# Depth=7, Estimators=27, f1 score=0.5234899328859061
# Depth=7, Estimators=28, f1 score=0.5267379679144385
# Depth=7, Estimators=29, f1 score=0.5208053691275167
# Depth=7, Estimators=30, f1 score=0.5188172043010753
# Depth=7, Estimators=31, f1 score=0.5187165775401069
# Depth=7, Estimators=32, f1 score=0.5227882037533512
# Depth=7, Estimators=33, f1 score=0.5248990578734859
# Depth=7, Estimators=34, f1 score=0.5274431057563588
# Depth=7, Estimators=35, f1 score=0.5254691689008043
# Depth=7, Estimators=36, f1 score=0.5267379679144385
# Depth=7, Estimators=37, f1 score=0.5333333333333333
# Depth=7, Estimators=38, f1 score=0.5306666666666666
# Depth=7, Estimators=39, f1 score=0.5294117647058824
# Depth=7, Estimators=40, f1 score=0.5352862849533955
# Depth=7, Estimators=41, f1 score=0.5326231691078562
# Depth=7, Estimators=42, f1 score=0.5370370370370371
# Depth=7, Estimators=43, f1 score=0.5299600532623169
# Depth=7, Estimators=44, f1 score=0.5347593582887701
# Depth=7, Estimators=45, f1 score=0.5320855614973262
# Depth=7, Estimators=46, f1 score=0.5267379679144385
# Depth=7, Estimators=47, f1 score=0.5260347129506008
# Depth=7, Estimators=48, f1 score=0.5226666666666666
# Depth=7, Estimators=49, f1 score=0.5246338215712384
# Depth=7, Estimators=50, f1 score=0.5233644859813084
# Depth=8, Estimators=1, f1 score=0.49099099099099097
# Depth=8, Estimators=2, f1 score=0.49514563106796117
# Depth=8, Estimators=3, f1 score=0.491183879093199
# Depth=8, Estimators=4, f1 score=0.49936948297604034
# Depth=8, Estimators=5, f1 score=0.5176767676767676
# Depth=8, Estimators=6, f1 score=0.5231958762886598
# Depth=8, Estimators=7, f1 score=0.5391527599486521
# Depth=8, Estimators=8, f1 score=0.5426356589147286
# Depth=8, Estimators=9, f1 score=0.537467700258398
# Depth=8, Estimators=10, f1 score=0.5395590142671854
# Depth=8, Estimators=11, f1 score=0.5459249676584734
# Depth=8, Estimators=12, f1 score=0.5447470817120622
# Depth=8, Estimators=13, f1 score=0.5416666666666666
# Depth=8, Estimators=14, f1 score=0.5470967741935484
# Depth=8, Estimators=15, f1 score=0.5407503234152652
# Depth=8, Estimators=16, f1 score=0.5405405405405406
# Depth=8, Estimators=17, f1 score=0.5373525557011796
# Depth=8, Estimators=18, f1 score=0.5321100917431193
# Depth=8, Estimators=19, f1 score=0.5399737876802096
# Depth=8, Estimators=20, f1 score=0.5452196382428941
# Depth=8, Estimators=21, f1 score=0.541507024265645
# Depth=8, Estimators=22, f1 score=0.5391527599486521
# Depth=8, Estimators=23, f1 score=0.5461538461538461
# Depth=8, Estimators=24, f1 score=0.5480153649167734
# Depth=8, Estimators=25, f1 score=0.5510204081632653
# Depth=8, Estimators=26, f1 score=0.5524296675191815
# Depth=8, Estimators=27, f1 score=0.5480153649167734
# Depth=8, Estimators=28, f1 score=0.5433673469387755
# Depth=8, Estimators=29, f1 score=0.5447570332480819
# Depth=8, Estimators=30, f1 score=0.5440613026819924
# Depth=8, Estimators=31, f1 score=0.5454545454545454
# Depth=8, Estimators=32, f1 score=0.5473145780051151
# Depth=8, Estimators=33, f1 score=0.5461538461538461
# Depth=8, Estimators=34, f1 score=0.5480153649167734
# Depth=8, Estimators=35, f1 score=0.5491698595146871
# Depth=8, Estimators=36, f1 score=0.5510204081632653
# Depth=8, Estimators=37, f1 score=0.5554140127388535
# Depth=8, Estimators=38, f1 score=0.5510204081632653
# Depth=8, Estimators=39, f1 score=0.5514612452350699
# Depth=8, Estimators=40, f1 score=0.5514612452350699
# Depth=8, Estimators=41, f1 score=0.5489199491740788
# Depth=8, Estimators=42, f1 score=0.5489199491740788
# Depth=8, Estimators=43, f1 score=0.549618320610687
# Depth=8, Estimators=44, f1 score=0.5491698595146871
# Depth=8, Estimators=45, f1 score=0.5503184713375796
# Depth=8, Estimators=46, f1 score=0.5498721227621484
# Depth=8, Estimators=47, f1 score=0.5473145780051151
# Depth=8, Estimators=48, f1 score=0.5491698595146871
# Depth=8, Estimators=49, f1 score=0.5512820512820513
# Depth=8, Estimators=50, f1 score=0.5512820512820513
# Depth=9, Estimators=1, f1 score=0.48398576512455516
# Depth=9, Estimators=2, f1 score=0.4492939666238768
# Depth=9, Estimators=3, f1 score=0.494148244473342
# Depth=9, Estimators=4, f1 score=0.4967989756722151
# Depth=9, Estimators=5, f1 score=0.5352112676056338
# Depth=9, Estimators=6, f1 score=0.5257731958762887
# Depth=9, Estimators=7, f1 score=0.5335018963337548
# Depth=9, Estimators=8, f1 score=0.5396419437340153
# Depth=9, Estimators=9, f1 score=0.5412960609911055
# Depth=9, Estimators=10, f1 score=0.5389527458492975
# Depth=9, Estimators=11, f1 score=0.5510204081632653
# Depth=9, Estimators=12, f1 score=0.5412371134020618
# Depth=9, Estimators=13, f1 score=0.55470737913486
# Depth=9, Estimators=14, f1 score=0.5435897435897435
# Depth=9, Estimators=15, f1 score=0.5435897435897435
# Depth=9, Estimators=16, f1 score=0.5480153649167734
# Depth=9, Estimators=17, f1 score=0.5456852791878173
# Depth=9, Estimators=18, f1 score=0.541507024265645
# Depth=9, Estimators=19, f1 score=0.5440613026819924
# Depth=9, Estimators=20, f1 score=0.5372750642673522
# Depth=9, Estimators=21, f1 score=0.5363984674329502
# Depth=9, Estimators=22, f1 score=0.5358974358974359
# Depth=9, Estimators=23, f1 score=0.5447570332480819
# Depth=9, Estimators=24, f1 score=0.5508365508365508
# Depth=9, Estimators=25, f1 score=0.5487179487179488
# Depth=9, Estimators=26, f1 score=0.5459249676584734
# Depth=9, Estimators=27, f1 score=0.5407503234152652
# Depth=9, Estimators=28, f1 score=0.5428571428571428
# Depth=9, Estimators=29, f1 score=0.5414507772020726
# Depth=9, Estimators=30, f1 score=0.5424164524421594
# Depth=9, Estimators=31, f1 score=0.5412371134020618
# Depth=9, Estimators=32, f1 score=0.5459249676584734
# Depth=9, Estimators=33, f1 score=0.5367741935483871
# Depth=9, Estimators=34, f1 score=0.538860103626943
# Depth=9, Estimators=35, f1 score=0.537467700258398
# Depth=9, Estimators=36, f1 score=0.5426356589147286
# Depth=9, Estimators=37, f1 score=0.5445161290322581
# Depth=9, Estimators=38, f1 score=0.5445161290322581
# Depth=9, Estimators=39, f1 score=0.5501285347043702
# Depth=9, Estimators=40, f1 score=0.5501285347043702
# Depth=9, Estimators=41, f1 score=0.55198973042362
# Depth=9, Estimators=42, f1 score=0.5526992287917738
# Depth=9, Estimators=43, f1 score=0.5478036175710594
# Depth=9, Estimators=44, f1 score=0.5496774193548387
# Depth=9, Estimators=45, f1 score=0.5492227979274611
# Depth=9, Estimators=46, f1 score=0.5478036175710594
# Depth=9, Estimators=47, f1 score=0.5459249676584734
# Depth=9, Estimators=48, f1 score=0.5428571428571428
# Depth=9, Estimators=49, f1 score=0.5428571428571428
# Depth=9, Estimators=50, f1 score=0.5435630689206762
# Depth=10, Estimators=1, f1 score=0.4502994011976048
# Depth=10, Estimators=2, f1 score=0.4793388429752066
# Depth=10, Estimators=3, f1 score=0.5130111524163569
# Depth=10, Estimators=4, f1 score=0.49051833122629585
# Depth=10, Estimators=5, f1 score=0.5252774352651048
# Depth=10, Estimators=6, f1 score=0.5114503816793893
# Depth=10, Estimators=7, f1 score=0.5222929936305732
# Depth=10, Estimators=8, f1 score=0.5307692307692308
# Depth=10, Estimators=9, f1 score=0.5378787878787878
# Depth=10, Estimators=10, f1 score=0.5279187817258884
# Depth=10, Estimators=11, f1 score=0.5372005044136192
# Depth=10, Estimators=12, f1 score=0.5360303413400759
# Depth=10, Estimators=13, f1 score=0.5402010050251256
# Depth=10, Estimators=14, f1 score=0.5454545454545454
# Depth=10, Estimators=15, f1 score=0.5531914893617021
# Depth=10, Estimators=16, f1 score=0.5472887767969735
# Depth=10, Estimators=17, f1 score=0.5459119496855346
# Depth=10, Estimators=18, f1 score=0.5491183879093199
# Depth=10, Estimators=19, f1 score=0.5514612452350699
# Depth=10, Estimators=20, f1 score=0.5421994884910486
# Depth=10, Estimators=21, f1 score=0.5433673469387755
# Depth=10, Estimators=22, f1 score=0.5375796178343949
# Depth=10, Estimators=23, f1 score=0.5433673469387755
# Depth=10, Estimators=24, f1 score=0.5438373570520966
# Depth=10, Estimators=25, f1 score=0.5486725663716814
# Depth=10, Estimators=26, f1 score=0.5565438373570522
# Depth=10, Estimators=27, f1 score=0.5491698595146871
# Depth=10, Estimators=28, f1 score=0.55198973042362
# Depth=10, Estimators=29, f1 score=0.55198973042362
# Depth=10, Estimators=30, f1 score=0.5463917525773195
# Depth=10, Estimators=31, f1 score=0.5475578406169666
# Depth=10, Estimators=32, f1 score=0.5475578406169666
# Depth=10, Estimators=33, f1 score=0.5442875481386393
# Depth=10, Estimators=34, f1 score=0.5442875481386393
# Depth=10, Estimators=35, f1 score=0.5494223363286265
# Depth=10, Estimators=36, f1 score=0.5456885456885456
# Depth=10, Estimators=37, f1 score=0.5463917525773195
# Depth=10, Estimators=38, f1 score=0.5456885456885456
# Depth=10, Estimators=39, f1 score=0.5431145431145431
# Depth=10, Estimators=40, f1 score=0.5435897435897435
# Depth=10, Estimators=41, f1 score=0.5491698595146871
# Depth=10, Estimators=42, f1 score=0.5487179487179488
# Depth=10, Estimators=43, f1 score=0.5531370038412292
# Depth=10, Estimators=44, f1 score=0.5512820512820513
# Depth=10, Estimators=45, f1 score=0.5456885456885456
# Depth=10, Estimators=46, f1 score=0.5505761843790012
# Depth=10, Estimators=47, f1 score=0.5510204081632653
# Depth=10, Estimators=48, f1 score=0.5517241379310345
# Depth=10, Estimators=49, f1 score=0.5542784163473818
# Depth=10, Estimators=50, f1 score=0.5524296675191815
# Depth=11, Estimators=1, f1 score=0.4827586206896552
# Depth=11, Estimators=2, f1 score=0.4554913294797688
# Depth=11, Estimators=3, f1 score=0.5170387779083431
# Depth=11, Estimators=4, f1 score=0.5012165450121655
# Depth=11, Estimators=5, f1 score=0.5140758873929009
# Depth=11, Estimators=6, f1 score=0.5264452644526445
# Depth=11, Estimators=7, f1 score=0.538083538083538
# Depth=11, Estimators=8, f1 score=0.541871921182266
# Depth=11, Estimators=9, f1 score=0.5532435740514076
# Depth=11, Estimators=10, f1 score=0.5566502463054187
# Depth=11, Estimators=11, f1 score=0.5472392638036809
# Depth=11, Estimators=12, f1 score=0.5496932515337424
# Depth=11, Estimators=13, f1 score=0.5528255528255528
# Depth=11, Estimators=14, f1 score=0.554601226993865
# Depth=11, Estimators=15, f1 score=0.5577395577395577
# Depth=11, Estimators=16, f1 score=0.5526641883519207
# Depth=11, Estimators=17, f1 score=0.55980271270037
# Depth=11, Estimators=18, f1 score=0.5594059405940595
# Depth=11, Estimators=19, f1 score=0.5551425030978935
# Depth=11, Estimators=20, f1 score=0.5497512437810945
# Depth=11, Estimators=21, f1 score=0.5511221945137157
# Depth=11, Estimators=22, f1 score=0.5420326223337516
# Depth=11, Estimators=23, f1 score=0.5459119496855346
# Depth=11, Estimators=24, f1 score=0.5456821026282853
# Depth=11, Estimators=25, f1 score=0.5380710659898477
# Depth=11, Estimators=26, f1 score=0.5410872313527181
# Depth=11, Estimators=27, f1 score=0.5443037974683544
# Depth=11, Estimators=28, f1 score=0.550063371356147
# Depth=11, Estimators=29, f1 score=0.550063371356147
# Depth=11, Estimators=30, f1 score=0.5512010113780025
# Depth=11, Estimators=31, f1 score=0.5523329129886507
# Depth=11, Estimators=32, f1 score=0.547979797979798
# Depth=11, Estimators=33, f1 score=0.548469387755102
# Depth=11, Estimators=34, f1 score=0.5537294563843237
# Depth=11, Estimators=35, f1 score=0.5525982256020279
# Depth=11, Estimators=36, f1 score=0.5545796737766625
# Depth=11, Estimators=37, f1 score=0.5518987341772152
# Depth=11, Estimators=38, f1 score=0.5573770491803278
# Depth=11, Estimators=39, f1 score=0.5559748427672956
# Depth=11, Estimators=40, f1 score=0.5577889447236181
# Depth=11, Estimators=41, f1 score=0.5541561712846348
# Depth=11, Estimators=42, f1 score=0.5595984943538268
# Depth=11, Estimators=43, f1 score=0.5588972431077694
# Depth=11, Estimators=44, f1 score=0.5586034912718204
# Depth=11, Estimators=45, f1 score=0.556390977443609
# Depth=11, Estimators=46, f1 score=0.5570890840652447
# Depth=11, Estimators=47, f1 score=0.5545796737766625
# Depth=11, Estimators=48, f1 score=0.5575
# Depth=11, Estimators=49, f1 score=0.555
# Depth=11, Estimators=50, f1 score=0.5509433962264151
# Depth=12, Estimators=1, f1 score=0.4721311475409836
# Depth=12, Estimators=2, f1 score=0.4496487119437939
# Depth=12, Estimators=3, f1 score=0.5241379310344828
# Depth=12, Estimators=4, f1 score=0.4994026284348865
# Depth=12, Estimators=5, f1 score=0.5089605734767025
# Depth=12, Estimators=6, f1 score=0.5153374233128835
# Depth=12, Estimators=7, f1 score=0.5281173594132029
# Depth=12, Estimators=8, f1 score=0.5278810408921933
# Depth=12, Estimators=9, f1 score=0.5409429280397022
# Depth=12, Estimators=10, f1 score=0.5376078914919852
# Depth=12, Estimators=11, f1 score=0.541871921182266
# Depth=12, Estimators=12, f1 score=0.5359801488833746
# Depth=12, Estimators=13, f1 score=0.53
# Depth=12, Estimators=14, f1 score=0.5361596009975063
# Depth=12, Estimators=15, f1 score=0.5375
# Depth=12, Estimators=16, f1 score=0.5468164794007491
# Depth=12, Estimators=17, f1 score=0.5461346633416458
# Depth=12, Estimators=18, f1 score=0.5440806045340051
# Depth=12, Estimators=19, f1 score=0.5465994962216625
# Depth=12, Estimators=20, f1 score=0.55
# Depth=12, Estimators=21, f1 score=0.5523329129886507
# Depth=12, Estimators=22, f1 score=0.5506883604505632
# Depth=12, Estimators=23, f1 score=0.5518102372034956
# Depth=12, Estimators=24, f1 score=0.5468164794007491
# Depth=12, Estimators=25, f1 score=0.5488721804511278
# Depth=12, Estimators=26, f1 score=0.5486284289276808
# Depth=12, Estimators=27, f1 score=0.5475
# Depth=12, Estimators=28, f1 score=0.5513784461152882
# Depth=12, Estimators=29, f1 score=0.5463659147869674
# Depth=12, Estimators=30, f1 score=0.5484276729559748
# Depth=12, Estimators=31, f1 score=0.5484276729559748
# Depth=12, Estimators=32, f1 score=0.5433962264150943
# Depth=12, Estimators=33, f1 score=0.5488721804511278
# Depth=12, Estimators=34, f1 score=0.5445420326223338
# Depth=12, Estimators=35, f1 score=0.5525
# Depth=12, Estimators=36, f1 score=0.5525
# Depth=12, Estimators=37, f1 score=0.5518102372034956
# Depth=12, Estimators=38, f1 score=0.5525
# Depth=12, Estimators=39, f1 score=0.5614906832298137
# Depth=12, Estimators=40, f1 score=0.5600991325898389
# Depth=12, Estimators=41, f1 score=0.5540372670807453
# Depth=12, Estimators=42, f1 score=0.5611866501854141
# Depth=12, Estimators=43, f1 score=0.5572139303482587
# Depth=12, Estimators=44, f1 score=0.5568039950062422
# Depth=12, Estimators=45, f1 score=0.5529265255292652
# Depth=12, Estimators=46, f1 score=0.5506883604505632
# Depth=12, Estimators=47, f1 score=0.5470514429109159
# Depth=12, Estimators=48, f1 score=0.5475
# Depth=12, Estimators=49, f1 score=0.5452261306532663
# Depth=12, Estimators=50, f1 score=0.5481852315394243
# Depth=13, Estimators=1, f1 score=0.487551867219917
# Depth=13, Estimators=2, f1 score=0.43705463182897863
# Depth=13, Estimators=3, f1 score=0.5063583815028901
# Depth=13, Estimators=4, f1 score=0.5041816009557945
# Depth=13, Estimators=5, f1 score=0.5268065268065268
# Depth=13, Estimators=6, f1 score=0.5352449223416965
# Depth=13, Estimators=7, f1 score=0.5245508982035928
# Depth=13, Estimators=8, f1 score=0.5213154689403167
# Depth=13, Estimators=9, f1 score=0.5304136253041363
# Depth=13, Estimators=10, f1 score=0.5428226779252111
# Depth=13, Estimators=11, f1 score=0.5321992709599028
# Depth=13, Estimators=12, f1 score=0.5355850422195416
# Depth=13, Estimators=13, f1 score=0.534629404617254
# Depth=13, Estimators=14, f1 score=0.5309090909090909
# Depth=13, Estimators=15, f1 score=0.5330073349633252
# Depth=13, Estimators=16, f1 score=0.5361077111383109
# Depth=13, Estimators=17, f1 score=0.5408038976857491
# Depth=13, Estimators=18, f1 score=0.551640340218712
# Depth=13, Estimators=19, f1 score=0.5514705882352942
# Depth=13, Estimators=20, f1 score=0.559610705596107
# Depth=13, Estimators=21, f1 score=0.5467980295566502
# Depth=13, Estimators=22, f1 score=0.5574572127139364
# Depth=13, Estimators=23, f1 score=0.5536585365853659
# Depth=13, Estimators=24, f1 score=0.554601226993865
# Depth=13, Estimators=25, f1 score=0.5492610837438424
# Depth=13, Estimators=26, f1 score=0.5541871921182266
# Depth=13, Estimators=27, f1 score=0.5495049504950495
# Depth=13, Estimators=28, f1 score=0.5573366214549939
# Depth=13, Estimators=29, f1 score=0.5488257107540173
# Depth=13, Estimators=30, f1 score=0.5485854858548586
# Depth=13, Estimators=31, f1 score=0.5517241379310345
# Depth=13, Estimators=32, f1 score=0.5485854858548586
# Depth=13, Estimators=33, f1 score=0.5530864197530864
# Depth=13, Estimators=34, f1 score=0.5485854858548586
# Depth=13, Estimators=35, f1 score=0.553921568627451
# Depth=13, Estimators=36, f1 score=0.5535055350553506
# Depth=13, Estimators=37, f1 score=0.5591133004926109
# Depth=13, Estimators=38, f1 score=0.5608856088560885
# Depth=13, Estimators=39, f1 score=0.5665445665445665
# Depth=13, Estimators=40, f1 score=0.561963190184049
# Depth=13, Estimators=41, f1 score=0.5668711656441717
# Depth=13, Estimators=42, f1 score=0.5658056580565806
# Depth=13, Estimators=43, f1 score=0.5590062111801242
# Depth=13, Estimators=44, f1 score=0.55980271270037
# Depth=13, Estimators=45, f1 score=0.5583126550868487
# Depth=13, Estimators=46, f1 score=0.562962962962963
# Depth=13, Estimators=47, f1 score=0.5600991325898389
# Depth=13, Estimators=48, f1 score=0.554726368159204
# Depth=13, Estimators=49, f1 score=0.5558312655086849
# Depth=13, Estimators=50, f1 score=0.5607940446650124
# Depth=14, Estimators=1, f1 score=0.4714587737843552
# Depth=14, Estimators=2, f1 score=0.4178743961352657
# Depth=14, Estimators=3, f1 score=0.49209932279909707
# Depth=14, Estimators=4, f1 score=0.47342995169082125
# Depth=14, Estimators=5, f1 score=0.5069767441860465
# Depth=14, Estimators=6, f1 score=0.49818621523579204
# Depth=14, Estimators=7, f1 score=0.5319148936170213
# Depth=14, Estimators=8, f1 score=0.5175332527206772
# Depth=14, Estimators=9, f1 score=0.5409252669039146
# Depth=14, Estimators=10, f1 score=0.5341317365269461
# Depth=14, Estimators=11, f1 score=0.5367027677496992
# Depth=14, Estimators=12, f1 score=0.5157384987893463
# Depth=14, Estimators=13, f1 score=0.5286236297198539
# Depth=14, Estimators=14, f1 score=0.5295566502463054
# Depth=14, Estimators=15, f1 score=0.5352798053527981
# Depth=14, Estimators=16, f1 score=0.5351418002466092
# Depth=14, Estimators=17, f1 score=0.5463414634146342
# Depth=14, Estimators=18, f1 score=0.5389369592088998
# Depth=14, Estimators=19, f1 score=0.5454545454545454
# Depth=14, Estimators=20, f1 score=0.5514705882352942
# Depth=14, Estimators=21, f1 score=0.5525672371638142
# Depth=14, Estimators=22, f1 score=0.5510455104551045
# Depth=14, Estimators=23, f1 score=0.5517241379310345
# Depth=14, Estimators=24, f1 score=0.5515527950310559
# Depth=14, Estimators=25, f1 score=0.5591133004926109
# Depth=14, Estimators=26, f1 score=0.5481481481481482
# Depth=14, Estimators=27, f1 score=0.5445544554455446
# Depth=14, Estimators=28, f1 score=0.5477075588599752
# Depth=14, Estimators=29, f1 score=0.5540372670807453
# Depth=14, Estimators=30, f1 score=0.55
# Depth=14, Estimators=31, f1 score=0.5472636815920398
# Depth=14, Estimators=32, f1 score=0.5511221945137157
# Depth=14, Estimators=33, f1 score=0.5468164794007491
# Depth=14, Estimators=34, f1 score=0.5568039950062422
# Depth=14, Estimators=35, f1 score=0.5538847117794486
# Depth=14, Estimators=36, f1 score=0.5617977528089888
# Depth=14, Estimators=37, f1 score=0.5575
# Depth=14, Estimators=38, f1 score=0.5610972568578554
# Depth=14, Estimators=39, f1 score=0.5586034912718204
# Depth=14, Estimators=40, f1 score=0.5568039950062422
# Depth=14, Estimators=41, f1 score=0.5543071161048689
# Depth=14, Estimators=42, f1 score=0.5529265255292652
# Depth=14, Estimators=43, f1 score=0.5562422744128553
# Depth=14, Estimators=44, f1 score=0.5497512437810945
# Depth=14, Estimators=45, f1 score=0.5529265255292652
# Depth=14, Estimators=46, f1 score=0.5511221945137157
# Depth=14, Estimators=47, f1 score=0.5511221945137157
# Depth=14, Estimators=48, f1 score=0.55
# Depth=14, Estimators=49, f1 score=0.55
# Depth=14, Estimators=50, f1 score=0.5475
# Depth=15, Estimators=1, f1 score=0.48066875653082547
# Depth=15, Estimators=2, f1 score=0.4401041666666667
# Depth=15, Estimators=3, f1 score=0.4937428896473265
# Depth=15, Estimators=4, f1 score=0.46867167919799496
# Depth=15, Estimators=5, f1 score=0.4928909952606635
# Depth=15, Estimators=6, f1 score=0.4829329962073325
# Depth=15, Estimators=7, f1 score=0.5195729537366548
# Depth=15, Estimators=8, f1 score=0.5037406483790524
# Depth=15, Estimators=9, f1 score=0.520048602673147
# Depth=15, Estimators=10, f1 score=0.5055762081784386
# Depth=15, Estimators=11, f1 score=0.5281173594132029
# Depth=15, Estimators=12, f1 score=0.5187032418952618
# Depth=15, Estimators=13, f1 score=0.5430303030303031
# Depth=15, Estimators=14, f1 score=0.5338253382533825
# Depth=15, Estimators=15, f1 score=0.5378973105134475
# Depth=15, Estimators=16, f1 score=0.5333333333333333
# Depth=15, Estimators=17, f1 score=0.5398773006134969
# Depth=15, Estimators=18, f1 score=0.5420792079207921
# Depth=15, Estimators=19, f1 score=0.5529841656516443
# Depth=15, Estimators=20, f1 score=0.5425400739827374
# Depth=15, Estimators=21, f1 score=0.5563725490196079
# Depth=15, Estimators=22, f1 score=0.547911547911548
# Depth=15, Estimators=23, f1 score=0.5532435740514076
# Depth=15, Estimators=24, f1 score=0.5398009950248757
# Depth=15, Estimators=25, f1 score=0.551980198019802
# Depth=15, Estimators=26, f1 score=0.5497512437810945
# Depth=15, Estimators=27, f1 score=0.5548705302096177
# Depth=15, Estimators=28, f1 score=0.5530864197530864
# Depth=15, Estimators=29, f1 score=0.5548705302096177
# Depth=15, Estimators=30, f1 score=0.5587144622991347
# Depth=15, Estimators=31, f1 score=0.5555555555555556
# Depth=15, Estimators=32, f1 score=0.5540372670807453
# Depth=15, Estimators=33, f1 score=0.5573366214549939
# Depth=15, Estimators=34, f1 score=0.553770086526576
# Depth=15, Estimators=35, f1 score=0.5555555555555556
# Depth=15, Estimators=36, f1 score=0.5541871921182266
# Depth=15, Estimators=37, f1 score=0.5544554455445545
# Depth=15, Estimators=38, f1 score=0.5551425030978935
# Depth=15, Estimators=39, f1 score=0.5526641883519207
# Depth=15, Estimators=40, f1 score=0.556930693069307
# Depth=15, Estimators=41, f1 score=0.5611866501854141
# Depth=15, Estimators=42, f1 score=0.5526641883519207
# Depth=15, Estimators=43, f1 score=0.5583126550868487
# Depth=15, Estimators=44, f1 score=0.553770086526576
# Depth=15, Estimators=45, f1 score=0.5608856088560885
# Depth=15, Estimators=46, f1 score=0.5576208178438662
# Depth=15, Estimators=47, f1 score=0.5611866501854141
# Depth=15, Estimators=48, f1 score=0.5593008739076155
# Depth=15, Estimators=49, f1 score=0.5597014925373134
# Depth=15, Estimators=50, f1 score=0.554726368159204
# Depth=16, Estimators=1, f1 score=0.455005055611729
# Depth=16, Estimators=2, f1 score=0.4153846153846154
# Depth=16, Estimators=3, f1 score=0.4682814302191465
# Depth=16, Estimators=4, f1 score=0.46017699115044247
# Depth=16, Estimators=5, f1 score=0.5046948356807511
# Depth=16, Estimators=6, f1 score=0.5012406947890818
# Depth=16, Estimators=7, f1 score=0.518957345971564
# Depth=16, Estimators=8, f1 score=0.5128205128205128
# Depth=16, Estimators=9, f1 score=0.5320665083135392
# Depth=16, Estimators=10, f1 score=0.5115712545676004
# Depth=16, Estimators=11, f1 score=0.5253012048192771
# Depth=16, Estimators=12, f1 score=0.5282555282555282
# Depth=16, Estimators=13, f1 score=0.526060606060606
# Depth=16, Estimators=14, f1 score=0.5184275184275184
# Depth=16, Estimators=15, f1 score=0.5205811138014528
# Depth=16, Estimators=16, f1 score=0.5104294478527608
# Depth=16, Estimators=17, f1 score=0.5127582017010935
# Depth=16, Estimators=18, f1 score=0.5177914110429448
# Depth=16, Estimators=19, f1 score=0.524390243902439
# Depth=16, Estimators=20, f1 score=0.526829268292683
# Depth=16, Estimators=21, f1 score=0.5315533980582524
# Depth=16, Estimators=22, f1 score=0.5297691373025516
# Depth=16, Estimators=23, f1 score=0.5279805352798054
# Depth=16, Estimators=24, f1 score=0.5304136253041363
# Depth=16, Estimators=25, f1 score=0.5315533980582524
# Depth=16, Estimators=26, f1 score=0.5304136253041363
# Depth=16, Estimators=27, f1 score=0.5328467153284672
# Depth=16, Estimators=28, f1 score=0.5304136253041363
# Depth=16, Estimators=29, f1 score=0.5310596833130329
# Depth=16, Estimators=30, f1 score=0.5374233128834356
# Depth=16, Estimators=31, f1 score=0.5325153374233129
# Depth=16, Estimators=32, f1 score=0.5400739827373613
# Depth=16, Estimators=33, f1 score=0.538083538083538
# Depth=16, Estimators=34, f1 score=0.5344827586206896
# Depth=16, Estimators=35, f1 score=0.5392156862745098
# Depth=16, Estimators=36, f1 score=0.5374233128834356
# Depth=16, Estimators=37, f1 score=0.5403422982885085
# Depth=16, Estimators=38, f1 score=0.5441176470588235
# Depth=16, Estimators=39, f1 score=0.5450121654501217
# Depth=16, Estimators=40, f1 score=0.5445665445665445
# Depth=16, Estimators=41, f1 score=0.5472154963680388
# Depth=16, Estimators=42, f1 score=0.5456760048721072
# Depth=16, Estimators=43, f1 score=0.5443499392466585
# Depth=16, Estimators=44, f1 score=0.5416666666666666
# Depth=16, Estimators=45, f1 score=0.5443499392466585
# Depth=16, Estimators=46, f1 score=0.5419198055893074
# Depth=16, Estimators=47, f1 score=0.5432399512789281
# Depth=16, Estimators=48, f1 score=0.5463414634146342
# Depth=16, Estimators=49, f1 score=0.5439024390243903
# Depth=16, Estimators=50, f1 score=0.5416666666666666
# Depth=17, Estimators=1, f1 score=0.47904191616766467
# Depth=17, Estimators=2, f1 score=0.41335044929396664
# Depth=17, Estimators=3, f1 score=0.49396267837541163
# Depth=17, Estimators=4, f1 score=0.46633416458852867
# Depth=17, Estimators=5, f1 score=0.5223367697594502
# Depth=17, Estimators=6, f1 score=0.5031133250311333
# Depth=17, Estimators=7, f1 score=0.5372781065088758
# Depth=17, Estimators=8, f1 score=0.5160493827160494
# Depth=17, Estimators=9, f1 score=0.5432977461447213
# Depth=17, Estimators=10, f1 score=0.5241038318912238
# Depth=17, Estimators=11, f1 score=0.5347721822541966
# Depth=17, Estimators=12, f1 score=0.528395061728395
# Depth=17, Estimators=13, f1 score=0.5491606714628298
# Depth=17, Estimators=14, f1 score=0.5487804878048781
# Depth=17, Estimators=15, f1 score=0.5570228091236494
# Depth=17, Estimators=16, f1 score=0.5427872860635696
# Depth=17, Estimators=17, f1 score=0.5452352231604343
# Depth=17, Estimators=18, f1 score=0.5456790123456791
# Depth=17, Estimators=19, f1 score=0.5439024390243903
# Depth=17, Estimators=20, f1 score=0.5364647713226205
# Depth=17, Estimators=21, f1 score=0.542997542997543
# Depth=17, Estimators=22, f1 score=0.5422885572139303
# Depth=17, Estimators=23, f1 score=0.5492610837438424
# Depth=17, Estimators=24, f1 score=0.5429638854296388
# Depth=17, Estimators=25, f1 score=0.5377942998760843
# Depth=17, Estimators=26, f1 score=0.5429638854296388
# Depth=17, Estimators=27, f1 score=0.5447852760736196
# Depth=17, Estimators=28, f1 score=0.546583850931677
# Depth=17, Estimators=29, f1 score=0.553921568627451
# Depth=17, Estimators=30, f1 score=0.546353522867738
# Depth=17, Estimators=31, f1 score=0.541871921182266
# Depth=17, Estimators=32, f1 score=0.543424317617866
# Depth=17, Estimators=33, f1 score=0.5443349753694581
# Depth=17, Estimators=34, f1 score=0.5422885572139303
# Depth=17, Estimators=35, f1 score=0.5400739827373613
# Depth=17, Estimators=36, f1 score=0.5409429280397022
# Depth=17, Estimators=37, f1 score=0.5400739827373613
# Depth=17, Estimators=38, f1 score=0.5396039603960396
# Depth=17, Estimators=39, f1 score=0.5400739827373613
# Depth=17, Estimators=40, f1 score=0.5384615384615384
# Depth=17, Estimators=41, f1 score=0.5474722564734895
# Depth=17, Estimators=42, f1 score=0.5452292441140025
# Depth=17, Estimators=43, f1 score=0.553921568627451
# Depth=17, Estimators=44, f1 score=0.546353522867738
# Depth=17, Estimators=45, f1 score=0.5535055350553506
# Depth=17, Estimators=46, f1 score=0.5524044389642416
# Depth=17, Estimators=47, f1 score=0.5528255528255528
# Depth=17, Estimators=48, f1 score=0.5438813349814586
# Depth=17, Estimators=49, f1 score=0.5503685503685504
# Depth=17, Estimators=50, f1 score=0.5432098765432098
# Depth=18, Estimators=1, f1 score=0.48554913294797686
# Depth=18, Estimators=2, f1 score=0.41830065359477125
# Depth=18, Estimators=3, f1 score=0.4911894273127753
# Depth=18, Estimators=4, f1 score=0.4837905236907731
# Depth=18, Estimators=5, f1 score=0.5113636363636364
# Depth=18, Estimators=6, f1 score=0.4835443037974684
# Depth=18, Estimators=7, f1 score=0.5322391559202814
# Depth=18, Estimators=8, f1 score=0.5194479297365119
# Depth=18, Estimators=9, f1 score=0.5499412455934195
# Depth=18, Estimators=10, f1 score=0.5427509293680297
# Depth=18, Estimators=11, f1 score=0.5592417061611374
# Depth=18, Estimators=12, f1 score=0.543424317617866
# Depth=18, Estimators=13, f1 score=0.5563549160671463
# Depth=18, Estimators=14, f1 score=0.5416149068322982
# Depth=18, Estimators=15, f1 score=0.5550239234449761
# Depth=18, Estimators=16, f1 score=0.5407407407407407
# Depth=18, Estimators=17, f1 score=0.5607701564380265
# Depth=18, Estimators=18, f1 score=0.5456790123456791
# Depth=18, Estimators=19, f1 score=0.5562273276904474
# Depth=18, Estimators=20, f1 score=0.5476772616136919
# Depth=18, Estimators=21, f1 score=0.5569007263922519
# Depth=18, Estimators=22, f1 score=0.5398773006134969
# Depth=18, Estimators=23, f1 score=0.5503030303030303
# Depth=18, Estimators=24, f1 score=0.5436654366543665
# Depth=18, Estimators=25, f1 score=0.5551515151515152
# Depth=18, Estimators=26, f1 score=0.5485854858548586
# Depth=18, Estimators=27, f1 score=0.558645707376058
# Depth=18, Estimators=28, f1 score=0.5548705302096177
# Depth=18, Estimators=29, f1 score=0.5532435740514076
# Depth=18, Estimators=30, f1 score=0.5530864197530864
# Depth=18, Estimators=31, f1 score=0.5567765567765568
# Depth=18, Estimators=32, f1 score=0.5524044389642416
# Depth=18, Estimators=33, f1 score=0.5565006075334143
# Depth=18, Estimators=34, f1 score=0.5506172839506173
# Depth=18, Estimators=35, f1 score=0.559610705596107
# Depth=18, Estimators=36, f1 score=0.5530864197530864
# Depth=18, Estimators=37, f1 score=0.5556915544675642
# Depth=18, Estimators=38, f1 score=0.5530864197530864
# Depth=18, Estimators=39, f1 score=0.5528255528255528
# Depth=18, Estimators=40, f1 score=0.5526641883519207
# Depth=18, Estimators=41, f1 score=0.5510455104551045
# Depth=18, Estimators=42, f1 score=0.5515527950310559
# Depth=18, Estimators=43, f1 score=0.5524044389642416
# Depth=18, Estimators=44, f1 score=0.553770086526576
# Depth=18, Estimators=45, f1 score=0.553921568627451
# Depth=18, Estimators=46, f1 score=0.554726368159204
# Depth=18, Estimators=47, f1 score=0.5558312655086849
# Depth=18, Estimators=48, f1 score=0.5527638190954773
# Depth=18, Estimators=49, f1 score=0.5565217391304348
# Depth=18, Estimators=50, f1 score=0.5481852315394243
# Depth=19, Estimators=1, f1 score=0.4453360080240722
# Depth=19, Estimators=2, f1 score=0.37917222963951935
# Depth=19, Estimators=3, f1 score=0.49023861171366595
# Depth=19, Estimators=4, f1 score=0.465
# Depth=19, Estimators=5, f1 score=0.49658314350797267
# Depth=19, Estimators=6, f1 score=0.4837905236907731
# Depth=19, Estimators=7, f1 score=0.5174825174825175
# Depth=19, Estimators=8, f1 score=0.5185185185185185
# Depth=19, Estimators=9, f1 score=0.5411764705882353
# Depth=19, Estimators=10, f1 score=0.5215252152521526
# Depth=19, Estimators=11, f1 score=0.541813898704358
# Depth=19, Estimators=12, f1 score=0.529192546583851
# Depth=19, Estimators=13, f1 score=0.5463182897862233
# Depth=19, Estimators=14, f1 score=0.5310173697270472
# Depth=19, Estimators=15, f1 score=0.5554231227651967
# Depth=19, Estimators=16, f1 score=0.5382716049382716
# Depth=19, Estimators=17, f1 score=0.5500603136308806
# Depth=19, Estimators=18, f1 score=0.5384615384615384
# Depth=19, Estimators=19, f1 score=0.5509708737864077
# Depth=19, Estimators=20, f1 score=0.5452292441140025
# Depth=19, Estimators=21, f1 score=0.5576923076923077
# Depth=19, Estimators=22, f1 score=0.5499383477188656
# Depth=19, Estimators=23, f1 score=0.5589307411907655
# Depth=19, Estimators=24, f1 score=0.5488257107540173
# Depth=19, Estimators=25, f1 score=0.5507246376811594
# Depth=19, Estimators=26, f1 score=0.5577395577395577
# Depth=19, Estimators=27, f1 score=0.5676328502415459
# Depth=19, Estimators=28, f1 score=0.5587144622991347
# Depth=19, Estimators=29, f1 score=0.5647921760391198
# Depth=19, Estimators=30, f1 score=0.5558312655086849
# Depth=19, Estimators=31, f1 score=0.5592185592185592
# Depth=19, Estimators=32, f1 score=0.5526641883519207
# Depth=19, Estimators=33, f1 score=0.5669099756690997
# Depth=19, Estimators=34, f1 score=0.5580246913580247
# Depth=19, Estimators=35, f1 score=0.5599022004889975
# ...
# Depth=19, Estimators=47, f1 score=0.5612745098039216
# Depth=19, Estimators=48, f1 score=0.5600991325898389
# Depth=19, Estimators=49, f1 score=0.5612745098039216
# Depth=19, Estimators=50, f1 score=0.5591133004926109
# Depth=20, Estimators=1, f1 score=0.4346153846153846
# Depth=20, Estimators=2, f1 score=0.37583892617449666
# Depth=20, Estimators=3, f1 score=0.4861407249466951
# Depth=20, Estimators=4, f1 score=0.44387755102040816
# Depth=20, Estimators=5, f1 score=0.5174353205849269
# Depth=20, Estimators=6, f1 score=0.49746192893401014
# Depth=20, Estimators=7, f1 score=0.5205479452054794
# Depth=20, Estimators=8, f1 score=0.506832298136646
# Depth=20, Estimators=9, f1 score=0.5283893395133256
# Depth=20, Estimators=10, f1 score=0.5149253731343284
# Depth=20, Estimators=11, f1 score=0.5341176470588235
# Depth=20, Estimators=12, f1 score=0.5086848635235732
# Depth=20, Estimators=13, f1 score=0.530952380952381
# Depth=20, Estimators=14, f1 score=0.5242236024844721
# Depth=20, Estimators=15, f1 score=0.5289855072463768
# Depth=20, Estimators=16, f1 score=0.5194479297365119
# Depth=20, Estimators=17, f1 score=0.5281173594132029
# Depth=20, Estimators=18, f1 score=0.5251256281407035
# Depth=20, Estimators=19, f1 score=0.5317073170731708
# Depth=20, Estimators=20, f1 score=0.5251256281407035
# Depth=20, Estimators=21, f1 score=0.5323565323565324
# Depth=20, Estimators=22, f1 score=0.5225
# Depth=20, Estimators=23, f1 score=0.5294117647058824
# Depth=20, Estimators=24, f1 score=0.5162907268170426
# Depth=20, Estimators=25, f1 score=0.5331695331695332
# Depth=20, Estimators=26, f1 score=0.5301507537688442
# Depth=20, Estimators=27, f1 score=0.5356265356265356
# Depth=20, Estimators=28, f1 score=0.5301507537688442
# Depth=20, Estimators=29, f1 score=0.5436654366543665
# Depth=20, Estimators=30, f1 score=0.5375
# Depth=20, Estimators=31, f1 score=0.5481481481481482
# Depth=20, Estimators=32, f1 score=0.54
# Depth=20, Estimators=33, f1 score=0.5436654366543665
# Depth=20, Estimators=34, f1 score=0.5363408521303258
# Depth=20, Estimators=35, f1 score=0.5427509293680297
# Depth=20, Estimators=36, f1 score=0.5381727158948686
# Depth=20, Estimators=37, f1 score=0.5481481481481482
# Depth=20, Estimators=38, f1 score=0.531328320802005
# Depth=20, Estimators=39, f1 score=0.5474722564734895
# Depth=20, Estimators=40, f1 score=0.5404732254047323
# Depth=20, Estimators=41, f1 score=0.5496932515337424
# Depth=20, Estimators=42, f1 score=0.5373134328358209
# Depth=20, Estimators=43, f1 score=0.5443349753694581
# Depth=20, Estimators=44, f1 score=0.535
# Depth=20, Estimators=45, f1 score=0.5409429280397022
# Depth=20, Estimators=46, f1 score=0.5398009950248757
# Depth=20, Estimators=47, f1 score=0.5394088669950738
# Depth=20, Estimators=48, f1 score=0.5429638854296388
# Depth=20, Estimators=49, f1 score=0.5450061652281134
# Depth=20, Estimators=50, f1 score=0.545
# Depth=21, Estimators=1, f1 score=0.47378640776699027
# Depth=21, Estimators=2, f1 score=0.42302543507362783
# Depth=21, Estimators=3, f1 score=0.49069003285870755
# Depth=21, Estimators=4, f1 score=0.4565499351491569
# Depth=21, Estimators=5, f1 score=0.5108323831242874
# Depth=21, Estimators=6, f1 score=0.4649350649350649
# Depth=21, Estimators=7, f1 score=0.508833922261484
# Depth=21, Estimators=8, f1 score=0.4923469387755102
# Depth=21, Estimators=9, f1 score=0.5325443786982249
# Depth=21, Estimators=10, f1 score=0.49936628643852976
# Depth=21, Estimators=11, f1 score=0.5304659498207885
# Depth=21, Estimators=12, f1 score=0.515
# Depth=21, Estimators=13, f1 score=0.5323741007194245
# Depth=21, Estimators=14, f1 score=0.5131414267834794
# Depth=21, Estimators=15, f1 score=0.5346062052505967
# Depth=21, Estimators=16, f1 score=0.5211970074812967
# Depth=21, Estimators=17, f1 score=0.5413173652694611
# Depth=21, Estimators=18, f1 score=0.529338327091136
# Depth=21, Estimators=19, f1 score=0.5430303030303031
# Depth=21, Estimators=20, f1 score=0.5238095238095238
# Depth=21, Estimators=21, f1 score=0.54632972322503
# Depth=21, Estimators=22, f1 score=0.5280199252801993
# Depth=21, Estimators=23, f1 score=0.5330073349633252
# Depth=21, Estimators=24, f1 score=0.5257861635220126
# Depth=21, Estimators=25, f1 score=0.5361077111383109
# Depth=21, Estimators=26, f1 score=0.5264483627204031
# Depth=21, Estimators=27, f1 score=0.5382716049382716
# Depth=21, Estimators=28, f1 score=0.5328282828282829
# Depth=21, Estimators=29, f1 score=0.5344827586206896
# Depth=21, Estimators=30, f1 score=0.5269761606022585
# Depth=21, Estimators=31, f1 score=0.5441176470588235
# Depth=21, Estimators=32, f1 score=0.5269761606022585
# Depth=21, Estimators=33, f1 score=0.5423312883435583
# Depth=21, Estimators=34, f1 score=0.5283018867924528
# Depth=21, Estimators=35, f1 score=0.5454545454545454
# Depth=21, Estimators=36, f1 score=0.5343320848938826
# Depth=21, Estimators=37, f1 score=0.547911547911548
# Depth=21, Estimators=38, f1 score=0.5331664580725908
# Depth=21, Estimators=39, f1 score=0.5425400739827374
# Depth=21, Estimators=40, f1 score=0.5318352059925093
# Depth=21, Estimators=41, f1 score=0.5432098765432098
# Depth=21, Estimators=42, f1 score=0.54
# Depth=21, Estimators=43, f1 score=0.5474722564734895
# Depth=21, Estimators=44, f1 score=0.5395232120451694
# Depth=21, Estimators=45, f1 score=0.5481481481481482
# Depth=21, Estimators=46, f1 score=0.5379825653798257
# Depth=21, Estimators=47, f1 score=0.5450061652281134
# Depth=21, Estimators=48, f1 score=0.5461346633416458
# Depth=21, Estimators=49, f1 score=0.5474722564734895
# Depth=21, Estimators=50, f1 score=0.5440993788819876
# Depth=22, Estimators=1, f1 score=0.4626865671641791
# Depth=22, Estimators=2, f1 score=0.38971583220568334
# Depth=22, Estimators=3, f1 score=0.4774193548387097
# Depth=22, Estimators=4, f1 score=0.4308093994778068
# Depth=22, Estimators=5, f1 score=0.484304932735426
# Depth=22, Estimators=6, f1 score=0.45302445302445304
# Depth=22, Estimators=7, f1 score=0.4936562860438293
# Depth=22, Estimators=8, f1 score=0.48621553884711777
# Depth=22, Estimators=9, f1 score=0.5261932479627474
# Depth=22, Estimators=10, f1 score=0.49747474747474746
# Depth=22, Estimators=11, f1 score=0.5214285714285715
# Depth=22, Estimators=12, f1 score=0.4968789013732834
# Depth=22, Estimators=13, f1 score=0.5225653206650831
# Depth=22, Estimators=14, f1 score=0.5147783251231527
# Depth=22, Estimators=15, f1 score=0.5275779376498801
# Depth=22, Estimators=16, f1 score=0.5105853051058531
# Depth=22, Estimators=17, f1 score=0.5387365911799762
# Depth=22, Estimators=18, f1 score=0.5259259259259259
# Depth=22, Estimators=19, f1 score=0.5362318840579711
# Depth=22, Estimators=20, f1 score=0.5311720698254364
# Depth=22, Estimators=21, f1 score=0.5355850422195416
# Depth=22, Estimators=22, f1 score=0.5267080745341615
# Depth=22, Estimators=23, f1 score=0.5355850422195416
# Depth=22, Estimators=24, f1 score=0.5298507462686567
# Depth=22, Estimators=25, f1 score=0.5368802902055623
# Depth=22, Estimators=26, f1 score=0.5308641975308642
# Depth=22, Estimators=27, f1 score=0.5423728813559322
# Depth=22, Estimators=28, f1 score=0.5364647713226205
# Depth=22, Estimators=29, f1 score=0.5441354292623942
# Depth=22, Estimators=30, f1 score=0.5382716049382716
# Depth=22, Estimators=31, f1 score=0.5483091787439613
# Depth=22, Estimators=32, f1 score=0.5376078914919852
# Depth=22, Estimators=33, f1 score=0.5415162454873647
# Depth=22, Estimators=34, f1 score=0.5364647713226205
# Depth=22, Estimators=35, f1 score=0.5500603136308806
# Depth=22, Estimators=36, f1 score=0.5441176470588235
# Depth=22, Estimators=37, f1 score=0.5478787878787879
# Depth=22, Estimators=38, f1 score=0.5443349753694581
# Depth=22, Estimators=39, f1 score=0.5507246376811594
# Depth=22, Estimators=40, f1 score=0.5454545454545454
# Depth=22, Estimators=41, f1 score=0.5587529976019184
# Depth=22, Estimators=42, f1 score=0.5461254612546126
# Depth=22, Estimators=43, f1 score=0.5579710144927537
# Depth=22, Estimators=44, f1 score=0.5472392638036809
# Depth=22, Estimators=45, f1 score=0.5540704738760632
# Depth=22, Estimators=46, f1 score=0.5472392638036809
# Depth=22, Estimators=47, f1 score=0.5456760048721072
# Depth=22, Estimators=48, f1 score=0.5427509293680297
# Depth=22, Estimators=49, f1 score=0.5454545454545454
# Depth=22, Estimators=50, f1 score=0.546353522867738
# Depth=23, Estimators=1, f1 score=0.45294117647058824
# Depth=23, Estimators=2, f1 score=0.39344262295081966
# Depth=23, Estimators=3, f1 score=0.47734806629834253
# Depth=23, Estimators=4, f1 score=0.45646437994722955
# Depth=23, Estimators=5, f1 score=0.49827784156142363
# Depth=23, Estimators=6, f1 score=0.4579560155239327
# Depth=23, Estimators=7, f1 score=0.5075669383003493
# Depth=23, Estimators=8, f1 score=0.4777636594663278
# Depth=23, Estimators=9, f1 score=0.5176470588235295
# Depth=23, Estimators=10, f1 score=0.49557522123893805
# Depth=23, Estimators=11, f1 score=0.5251798561151079
# Depth=23, Estimators=12, f1 score=0.5056039850560399
# Depth=23, Estimators=13, f1 score=0.5234093637454982
# Depth=23, Estimators=14, f1 score=0.5119798234552333
# Depth=23, Estimators=15, f1 score=0.5235223160434258
# Depth=23, Estimators=16, f1 score=0.5137844611528822
# Depth=23, Estimators=17, f1 score=0.5272067714631197
# Depth=23, Estimators=18, f1 score=0.5219573400250941
# Depth=23, Estimators=19, f1 score=0.5336597307221542
# Depth=23, Estimators=20, f1 score=0.5294855708908407
# Depth=23, Estimators=21, f1 score=0.5323565323565324
# Depth=23, Estimators=22, f1 score=0.5232704402515723
# Depth=23, Estimators=23, f1 score=0.5239852398523985
# Depth=23, Estimators=24, f1 score=0.53
# Depth=23, Estimators=25, f1 score=0.5458996328029376
# Depth=23, Estimators=26, f1 score=0.534504391468005
# Depth=23, Estimators=27, f1 score=0.5361077111383109
# Depth=23, Estimators=28, f1 score=0.5418227215980025
# Depth=23, Estimators=29, f1 score=0.543451652386781
# Depth=23, Estimators=30, f1 score=0.535175879396985
# Depth=23, Estimators=31, f1 score=0.5456760048721072
# Depth=23, Estimators=32, f1 score=0.5363408521303258
# Depth=23, Estimators=33, f1 score=0.5540704738760632
# Depth=23, Estimators=34, f1 score=0.5393258426966292
# Depth=23, Estimators=35, f1 score=0.5532435740514076
# Depth=23, Estimators=36, f1 score=0.5522388059701493
# Depth=23, Estimators=37, f1 score=0.5566502463054187
# Depth=23, Estimators=38, f1 score=0.5554171855541719
# Depth=23, Estimators=39, f1 score=0.5612745098039216
# Depth=23, Estimators=40, f1 score=0.5533498759305211
# Depth=23, Estimators=41, f1 score=0.5605875152998776
# Depth=23, Estimators=42, f1 score=0.5544554455445545
# Depth=23, Estimators=43, f1 score=0.5507955936352509
# Depth=23, Estimators=44, f1 score=0.5504358655043586
# Depth=23, Estimators=45, f1 score=0.5514705882352942
# Depth=23, Estimators=46, f1 score=0.5497512437810945
# Depth=23, Estimators=47, f1 score=0.5518925518925519
# Depth=23, Estimators=48, f1 score=0.5511221945137157
# Depth=23, Estimators=49, f1 score=0.5530864197530864
# Depth=23, Estimators=50, f1 score=0.5572139303482587
# Depth=24, Estimators=1, f1 score=0.45294117647058824
# Depth=24, Estimators=2, f1 score=0.39344262295081966
# Depth=24, Estimators=3, f1 score=0.47734806629834253
# Depth=24, Estimators=4, f1 score=0.45646437994722955
# Depth=24, Estimators=5, f1 score=0.49827784156142363
# Depth=24, Estimators=6, f1 score=0.4579560155239327
# Depth=24, Estimators=7, f1 score=0.5075669383003493
# Depth=24, Estimators=8, f1 score=0.4777636594663278
# Depth=24, Estimators=9, f1 score=0.5176470588235295
# Depth=24, Estimators=10, f1 score=0.49557522123893805
# Depth=24, Estimators=11, f1 score=0.5251798561151079
# Depth=24, Estimators=12, f1 score=0.5056039850560399
# Depth=24, Estimators=13, f1 score=0.5234093637454982
# Depth=24, Estimators=14, f1 score=0.5125
# Depth=24, Estimators=15, f1 score=0.5275779376498801
# Depth=24, Estimators=16, f1 score=0.5087719298245614
# Depth=24, Estimators=17, f1 score=0.5341317365269461
# Depth=24, Estimators=18, f1 score=0.519546027742749
# Depth=24, Estimators=19, f1 score=0.5292682926829269
# Depth=24, Estimators=20, f1 score=0.5207547169811321
# Depth=24, Estimators=21, f1 score=0.5357575757575758
# Depth=24, Estimators=22, f1 score=0.5226130653266332
# Depth=24, Estimators=23, f1 score=0.5279805352798054
# Depth=24, Estimators=24, f1 score=0.5288220551378446
# Depth=24, Estimators=25, f1 score=0.5349693251533743
# Depth=24, Estimators=26, f1 score=0.5233881163084703
# Depth=24, Estimators=27, f1 score=0.5392156862745098
# Depth=24, Estimators=28, f1 score=0.5269761606022585
# Depth=24, Estimators=29, f1 score=0.543451652386781
# Depth=24, Estimators=30, f1 score=0.5269761606022585
# Depth=24, Estimators=31, f1 score=0.5416666666666666
# Depth=24, Estimators=32, f1 score=0.5391304347826087
# Depth=24, Estimators=33, f1 score=0.5474452554744526
# Depth=24, Estimators=34, f1 score=0.5318352059925093
# Depth=24, Estimators=35, f1 score=0.5472392638036809
# Depth=24, Estimators=36, f1 score=0.543640897755611
# Depth=24, Estimators=37, f1 score=0.5550122249388753
# Depth=24, Estimators=38, f1 score=0.547945205479452
# Depth=24, Estimators=39, f1 score=0.5585365853658537
# Depth=24, Estimators=40, f1 score=0.550185873605948
# Depth=24, Estimators=41, f1 score=0.558645707376058
# Depth=24, Estimators=42, f1 score=0.546353522867738
# Depth=24, Estimators=43, f1 score=0.5571776155717761
# Depth=24, Estimators=44, f1 score=0.5477075588599752
# Depth=24, Estimators=45, f1 score=0.5501222493887531
# Depth=24, Estimators=46, f1 score=0.5474722564734895
# Depth=24, Estimators=47, f1 score=0.5494505494505495
# Depth=24, Estimators=48, f1 score=0.5510455104551045
# Depth=24, Estimators=49, f1 score=0.5550122249388753
# Depth=24, Estimators=50, f1 score=0.5524044389642416
# Depth=25, Estimators=1, f1 score=0.45294117647058824
# Depth=25, Estimators=2, f1 score=0.39344262295081966
# Depth=25, Estimators=3, f1 score=0.47734806629834253
# Depth=25, Estimators=4, f1 score=0.45646437994722955
# Depth=25, Estimators=5, f1 score=0.49827784156142363
# Depth=25, Estimators=6, f1 score=0.4579560155239327
# Depth=25, Estimators=7, f1 score=0.5075669383003493
# Depth=25, Estimators=8, f1 score=0.4777636594663278
# Depth=25, Estimators=9, f1 score=0.5176470588235295
# Depth=25, Estimators=10, f1 score=0.49557522123893805
# Depth=25, Estimators=11, f1 score=0.5251798561151079
# Depth=25, Estimators=12, f1 score=0.5056039850560399
# Depth=25, Estimators=13, f1 score=0.5234093637454982
# Depth=25, Estimators=14, f1 score=0.5125
# Depth=25, Estimators=15, f1 score=0.5242718446601942
# Depth=25, Estimators=16, f1 score=0.5119798234552333
# Depth=25, Estimators=17, f1 score=0.5317365269461077
# Depth=25, Estimators=18, f1 score=0.519546027742749
# Depth=25, Estimators=19, f1 score=0.53836784409257
# Depth=25, Estimators=20, f1 score=0.5201005025125628
# Depth=25, Estimators=21, f1 score=0.5368802902055623
# Depth=25, Estimators=22, f1 score=0.5113350125944585
# Depth=25, Estimators=23, f1 score=0.5334957369062119
# Depth=25, Estimators=24, f1 score=0.5232704402515723
# Depth=25, Estimators=25, f1 score=0.5349693251533743
# Depth=25, Estimators=26, f1 score=0.535
# Depth=25, Estimators=27, f1 score=0.543451652386781
# Depth=25, Estimators=28, f1 score=0.5319949811794228
# Depth=25, Estimators=29, f1 score=0.5445665445665445
# Depth=25, Estimators=30, f1 score=0.53
# Depth=25, Estimators=31, f1 score=0.5378973105134475
# Depth=25, Estimators=32, f1 score=0.5389369592088998
# Depth=25, Estimators=33, f1 score=0.5396825396825397
# Depth=25, Estimators=34, f1 score=0.5361596009975063
# Depth=25, Estimators=35, f1 score=0.5487804878048781
# Depth=25, Estimators=36, f1 score=0.5447761194029851
# Depth=25, Estimators=37, f1 score=0.554601226993865
# Depth=25, Estimators=38, f1 score=0.5513784461152882
# Depth=25, Estimators=39, f1 score=0.5555555555555556
# Depth=25, Estimators=40, f1 score=0.5495608531994981
# Depth=25, Estimators=41, f1 score=0.5485854858548586
# Depth=25, Estimators=42, f1 score=0.5493133583021224
# Depth=25, Estimators=43, f1 score=0.5499383477188656
# Depth=25, Estimators=44, f1 score=0.5486284289276808
# Depth=25, Estimators=45, f1 score=0.5488257107540173
# Depth=25, Estimators=46, f1 score=0.5522388059701493
# Depth=25, Estimators=47, f1 score=0.5535055350553506
# Depth=25, Estimators=48, f1 score=0.5522388059701493
# Depth=25, Estimators=49, f1 score=0.5559655596555966
# Depth=25, Estimators=50, f1 score=0.5544554455445545
# Best Depth: 19, Best Estimators: 27, Best f1 score: 0.5676328502415459

# %% [markdown]
# - Before model testing our data needed to be properly Encoded as well as split into: Training, Validation and Test sets.
# - Baselines of each model we produced before we address the issue of imbalance of classes. This will help us to better understand how the models are working as we address imbalance.
# - Of the 3 models tested: RandomForestClassifier ranks highest so far with an F1 Score of 0.56 and an Accuracy Score of 0.85.

# %% [markdown]
# ## Balancing Classes:

# %% [markdown]
# ### Class Weight:
# - For each model we will use the built in class_weight = 'balanced' parameter to account for the imbalance in our data.
# - Results will be compared to our baseline as well as further class balancing techniques.

# %%
# Logistic Regression with class_weight='balanced' and hyperparameter tuning
best_c = 0
best_f1 = 0
for c in [0.01, 0.1, 1, 10]:
    model = LogisticRegression(solver='liblinear', C=c, random_state=12345, class_weight='balanced')
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'C={c}, f1 score={current_f1}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_c = c
print(f'Best C with class_weight=balanced: {best_c}, Best f1 score: {best_f1}')
# Out:
# C=0.01, f1 score=0.4464871963230466
# C=0.1, f1 score=0.46630727762803237
# C=1, f1 score=0.4674278038952317
# C=10, f1 score=0.44041450777202074
# Best C with class_weight=balanced: 1, Best f1 score: 0.4674278038952317
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
# Decision Tree Classifier with class_weight='balanced' with hyperparameter tuning

best_depth = 0
best_f1 = 0
for depth in range(1, 11):
    model = DecisionTreeClassifier(max_depth=depth, random_state=12345, class_weight='balanced')
    model.fit(features_train, target_train)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'Depth={depth}, f1 score={current_f1}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_depth = depth
print(f'Best Depth with class_weight=balanced: {best_depth}, Best f1 score: {best_f1}')
# Out:
# Depth=1, f1 score=0.46296296296296297
# Depth=2, f1 score=0.49064449064449067
# Depth=3, f1 score=0.49064449064449067
# Depth=4, f1 score=0.5211267605633803
# Depth=5, f1 score=0.5325596389426177
# Depth=6, f1 score=0.5620805369127517
# Depth=7, f1 score=0.5476550680786687
# Depth=8, f1 score=0.5603305785123966
# Depth=9, f1 score=0.5103011093502378
# Depth=10, f1 score=0.5175292153589316
# Best Depth with class_weight=balanced: 6, Best f1 score: 0.5620805369127517

# %%
# Random Forest Classifier with class_weight='balanced' with hyperparameter tuning
best_depth = 0
best_f1 = 0
best_est = 0
for depth in range(1, 26):
    for est in range(1,51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345, class_weight='balanced')
        model.fit(features_train, target_train)
        predictions = model.predict(features_valid)
        current_f1 = f1_score(target_valid, predictions)
        #print(f'Depth={depth}, Estimators={est}, f1 score={current_f1}')
        if current_f1 > best_f1:
            best_f1 = current_f1
            best_depth = depth
            best_est = est
print(f'Best Depth with class_weight=balanced: {best_depth}, Best Estimators: {best_est}, Best f1 score: {best_f1}, Best accuracy score: {accuracy_score(target_valid, model.predict(features_valid))} ')
# Out:
# Best Depth with class_weight=balanced: 9, Best Estimators: 21, Best f1 score: 0.5928705440900562, Best accuracy score: 0.8488

# %% [markdown]
# - Initial efforts to account for class imbalance was to take the simplistic apprach of class_weight.
# - Each model was directed to used a balanced class weight.
# - The Logistic Regression model showed the most imporvement compared to baseline results with an improved F1 Score of 0.46.
# - However, all three models' F1 score improved with the implementation of our class balancing parameter.
# - Random Forest sets the bar with an F1 score of 0.59, impressive results!

# %% [markdown]
# ### Upsampling:
# - Through the use of upsampling we will now create balance in our data.
#     - Our minority class '1' is now roughly equal to the once significant majority class of '0'.
#     - Worth noting, our data now reflects just over 8,000 samples, down from the original 10,000 that we started with.
#     - This change in data is a by product of upsampling and isn't considered significant enough to effect the performance of our models.

# %%
features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.5, random_state=12345)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, target_valid, test_size=0.5, random_state=12345)

def upsample(features, target, repeat):
    features_ones = features[target == 1]
    target_ones = target[target == 1]
    features_zeros = features[target == 0]
    target_zeros = target[target == 0]
    
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']
scaler = StandardScaler()
scaler.fit(features_upsampled[numeric])
features_upsampled[numeric] = scaler.transform(features_upsampled[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

target_upsampled.value_counts().plot(kind='bar',rot=1)
plt.title('Class Distribution After Upsampling')
plt.show()
print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (8048, 11)
# (8048,)

# %%
# Logistic Regression hyperparameter tuning
best_c = 0
best_f1 = 0
for c in [0.01, 0.1, 1, 10]:
    model = LogisticRegression(solver='liblinear', random_state=12345, C=c)
    model.fit(features_upsampled, target_upsampled)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'C={c} => f1 score: {current_f1}, Accuracy Score: {accuracy_score(target_valid, predictions)}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_c = c
print(f'Best C: {best_c} with f1 score: {best_f1}')
# Out:
# C=0.01 => f1 score: 0.4584487534626039, Accuracy Score: 0.6872
# C=0.1 => f1 score: 0.45722108145106094, Accuracy Score: 0.6828
# C=1 => f1 score: 0.45702592087312416, Accuracy Score: 0.6816
# C=10 => f1 score: 0.45702592087312416, Accuracy Score: 0.6816
# Best C: 0.01 with f1 score: 0.4584487534626039
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
# Decision Tree hyperparameter tuning
best_f1 = 0
best_depth = 0
for depth in range(1, 21):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_upsampled, target_upsampled)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_depth = depth
print("Best max_depth:", best_depth)
print("Best f1 score on validation set:", best_f1)
# Out:
# Best max_depth: 8
# Best f1 score on validation set: 0.5589447650453421

# %%
# Random Forest hyperparameter tuning
best_score = 0
best_depth = 0
best_est=0
for depth in range(1, 26):
    for est in range(1, 51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345)
        model.fit(features_upsampled, target_upsampled)
        predictions = model.predict(features_valid)
        current_score = f1_score(target_valid, predictions)
        if current_score > best_score:
            best_score = current_score
            best_depth = depth
            best_est=est

print("Best max_depth:", best_depth)
print("Best est:", best_est)
print("Best F1 Score:", best_score)
print("Accuracy Score:",accuracy_score(target_valid, predictions))
# Out:
# Best max_depth: 21
# Best est: 37
# Best F1 Score: 0.5862068965517241
# Accuracy Score: 0.842
# Final Model Test Results:
# f1 score: 0.6248693834900731
# Accuracy Score: 0.8564
# AUC-ROC: 0.8452220132616393

# %% [markdown]
# - By Up Sampling we were able to change our class imbalance from a ratio of 4:1 to an almost perfect ratio of 1:1.
# - Results showed positive gain on F1 score compared to our initial models results on the unbalanced data.
# - Again Random Forest proves to be the leading model with respect to F1 score, however, even with the help of upsampling we didn't achieve a better F1 score than our 'balanced' model.

# %% [markdown]
# ### Downsampling:
# - Now we will conduct downsampling, the opposite of our previous testing:
#     - For downsampling we focus on reducing the majority class in order to find a balance with our minority class.
#     - Again we have a change in the quantity of our data due to the sampling.
#     - Downsampling has reduced our data from 10,000 to roughly 2000 samples.
#     - Unlike upsampling where we weren't concerned about the effects on the model, such a reduction on samples could prove difficult for our model to achieve the desired F1 score.

# %%
features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.5, random_state=12345)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, target_valid, test_size=0.5, random_state=12345)

def downsample(features, target):
    features_ones = features[target == 1]
    target_ones = target[target == 1]
    features_zeros = features[target == 0]
    target_zeros = target[target == 0]
    
    features_zeros_downsampled = features_zeros.sample(n=len(target_ones), random_state=12345)
    target_zeros_downsampled = target_zeros.sample(n=len(target_ones), random_state=12345)
    
    features_downsampled = pd.concat([features_zeros_downsampled, features_ones])
    target_downsampled = pd.concat([target_zeros_downsampled, target_ones])
    
    features_downsampled, target_downsampled = shuffle(features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train) 

numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']
scaler = StandardScaler()
scaler.fit(features_downsampled[numeric])
features_downsampled[numeric] = scaler.transform(features_downsampled[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

target_downsampled.value_counts().plot(kind='bar',rot=1)
plt.title('Class Distribution After Downsampling')
plt.show()
print(features_downsampled.shape)
print(target_downsampled.shape)
# Out:
# (2032, 11)
# (2032,)

# %%
# Logistic Regression hyperparameter tuning
best_c = 0
best_f1 = 0
for c in [0.01, 0.1, 1, 10]:
    model = LogisticRegression(solver='liblinear', random_state=12345, C=c)
    model.fit(features_downsampled, target_downsampled)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    print(f'C={c} => f1 score: {current_f1}, Accuracy Score: {accuracy_score(target_valid, predictions)}')
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_c = c
print(f'Best C: {best_c} with f1 score: {best_f1}')
# Out:
# C=0.01 => f1 score: 0.46839080459770116, Accuracy Score: 0.704
# C=0.1 => f1 score: 0.4540466392318244, Accuracy Score: 0.6816
# C=1 => f1 score: 0.44399460188933876, Accuracy Score: 0.6704
# C=10 => f1 score: 0.4430976430976431, Accuracy Score: 0.6692
# Best C: 0.01 with f1 score: 0.46839080459770116
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
# Decision Tree hyperparameter tuning
best_f1 = 0
best_depth = 0
for depth in range(1, 21):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_downsampled, target_downsampled)
    predictions = model.predict(features_valid)
    current_f1 = f1_score(target_valid, predictions)
    if current_f1 > best_f1:
        best_f1 = current_f1
        best_depth = depth
print("Best max_depth:", best_depth)
print("Best f1 score on validation set:", best_f1)
# Out:
# Best max_depth: 5
# Best f1 score on validation set: 0.5454545454545454

# %%
# Random Forest hyperparameter tuning
best_score = 0
best_depth = 0
best_est=0
for depth in range(1, 26):
    for est in range(1, 51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345)
        model.fit(features_downsampled, target_downsampled)
        predictions = model.predict(features_valid)
        current_score = f1_score(target_valid, predictions)
        if current_score > best_score:
            best_score = current_score
            best_depth = depth
            best_est=est
print("Best max_depth:", best_depth)
print("Best est:", best_est)
print("Best F1 Score:", best_score)
# Out:
# Best max_depth: 6
# Best est: 49
# Best F1 Score: 0.5583145221971407

# %% [markdown]
# - The results of downsampling are underwhelming.
# - While model performance wasn't terrible it certainly wasn't in the realm of our previous testing.
# - Even though we balanced the classes through downsampling, the lack of overall data, compared to other balancing techniques, keeps our models from achieving our desired F1 score.

# %% [markdown]
# ## Testing Best Model:
# - Testing will be conducted on 2 models due to similarities of results.
#     - First we will test the Random Forest on the Upsampled data.
#         - Achieved an F1 score of 0.58.
#     - Second we will test the Random Forest with the parameter 'balanced'.
#         - Achieved and F1 score of 0.59.
#
# - Below we will test our models against our test data sets.
#     - This data has been witheld from previous model's training/testing.
#     - Because the models haven't yet seen the data we will be able to get a good representation of how well our models can perform.
#     - Ultimately we are in search of a model that produces an F1 score greater than 0.59.

# %% [markdown]
# ### Random Forest on Upsampled Test Data:

# %%
# Random Forest hyperparameter tuning
best_score = 0
best_depth = 0
best_est=0
for depth in range(1, 26):
    for est in range(1, 51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345)
        model.fit(features_upsampled, target_upsampled)
        predictions = model.predict(features_valid)
        current_score = f1_score(target_valid, predictions)
        if current_score > best_score:
            best_score = current_score
            best_depth = depth
            best_est=est

print("Best max_depth:", best_depth)
print("Best est:", best_est)
print("Best F1 Score:", best_score)
print("Accuracy Score:",accuracy_score(target_valid, predictions))

# Final Model Test Results using Random Forest

print("Final Model Test Results:")
model = RandomForestClassifier(max_depth=best_depth, n_estimators=best_est, random_state=12345)
model.fit(features_upsampled, target_upsampled)
predictions = model.predict(features_test)
print('f1 score:',f1_score(target_test, predictions))
print('Accuracy Score:',accuracy_score(target_test, predictions))


probabilities = model.predict_proba(features_test)[:, 1]
fpr, tpr, thresholds = roc_curve(target_test, probabilities)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

print('AUC-ROC:', roc_auc_score(target_test, probabilities))
# Out:
# Best max_depth: 11
# Best est: 29
# Best F1 Score: 0.5908256880733945
# Accuracy Score: 0.842
# Final Model Test Results:
# f1 score: 0.6345454545454545
# Accuracy Score: 0.8392
# AUC-ROC: 0.8576527153593877

# %% [markdown]
# ### Random Forest Class Weight 'Balanced' on Test Data:

# %%
features_train, features_valid, target_train, target_valid = train_test_split(features, target, test_size=0.5, random_state=12345)
features_valid, features_test, target_valid, target_test = train_test_split(features_valid, target_valid, test_size=0.5, random_state=12345)

# Random Forest Classifier with class_weight='balanced' with hyperparameter tuning
best_depth = 0
best_f1 = 0
best_est = 0
for depth in range(1, 26):
    for est in range(1,51):
        model = RandomForestClassifier(max_depth=depth, n_estimators=est, random_state=12345, class_weight='balanced')
        model.fit(features_train, target_train)
        predictions = model.predict(features_valid)
        current_f1 = f1_score(target_valid, predictions)
        #print(f'Depth={depth}, Estimators={est}, f1 score={current_f1}')
        if current_f1 > best_f1:
            best_f1 = current_f1
            best_depth = depth
            best_est = est
print(f'Best Depth with class_weight=balanced: {best_depth}, Best Estimators: {best_est}, Best f1 score: {best_f1}')

# Final Model Test Results using Random Forest with class_weight='balanced'
print("Final Model Test Results with class_weight='balanced':")
model = RandomForestClassifier(max_depth=best_depth, n_estimators=best_est, random_state=12345, class_weight='balanced')
model.fit(features_train, target_train)
predictions = model.predict(features_test)
print('f1 score:',f1_score(target_test, predictions))
print('Accuracy Score:',accuracy_score(target_test, predictions))
probabilities = model.predict_proba(features_test)[:, 1]
fpr, tpr, thresholds = roc_curve(target_test, probabilities)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
print('AUC-ROC:', roc_auc_score(target_test, probabilities))
# Out:
# Best Depth with class_weight=balanced: 9, Best Estimators: 21, Best f1 score: 0.5928705440900562
# Final Model Test Results with class_weight='balanced':
# f1 score: 0.6139534883720931
# Accuracy Score: 0.834
# AUC-ROC: 0.8589290426760297

# %% [markdown]
# ## Conclusion:
#
# - After properly analyzing and preparing the data we have successfully achieved our goal of creating a model that can predict customer churn with an F1 Score greater than 0.59.
# - Our RandomForestClassifier model on upsampled data achieved an F1 Score of 0.63 with an AUC-ROC of 0.85.
# - Taking into account the ROC Curve you can all see that our model performs well across all thresholds.
# - While our model's AUC-ROC score isn't quite 0.9 we can still have extreme confidence in it's ability to predict customer churn, helping Beta Bank retain customers and save money.
#
# - Worth noting:
#     - Our class weight 'balanced' model did extremely well and achieved an F1 score of 0.61 with an AUC-ROC of 0.85.
#     - These results were more than enough to achieve the goal we set out to accomplish.
#     - The similarities between the two models is no mistake: upsampling and 'balanced' are achieved roughly the same way.
#         - While upsampling looks to balance data by increasing the minority class, class_weight 'balanced' adds weight to the minority class in effort to seek balance.
#         - Essentially our two techniques achieved the same goal of balancing the data, with the only real difference being the quantity of data between approaches.
